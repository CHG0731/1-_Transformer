# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir('/content/drive/MyDrive/모델 구현/1주차/transformer')

# %%
import torch
import torch.nn as nn
import numpy as np
import copy

def One_hot_encoding(x, vocab_size):
  # x : batch_size * sentence_length , 이미 단어가 정수로 표현되어 있다고 가정
  batch_size = x.size(0)
  sentence_length = x.size(1)

  one_hot_x = torch.zeros(batch_size, sentence_length, vocab_size).cuda()

  for i in range(batch_size):
    for j in range(sentence_length):
      one_hot_x[i][j][x[i][j]] = 1

  return one_hot_x

def Positional_encoding(x):
  # x는 embedding 된 x라고 가정
  batch_size = x.size(0)
  sentence_length = x.size(1)
  d_model = x.size(2)

  positional_encoding_x = torch.zeros(sentence_length, d_model).cuda()

  for pos in range(sentence_length):
    for i in range(d_model):
      if i % 2 == 0:
        positional_encoding_x[pos][i] = np.sin((pos + 1) / (10000 ** (float(i) / d_model)))
      else:
        positional_encoding_x[pos][i] = np.cos((pos + 1) / (10000 ** (float(i-1) / d_model)))

  positional_encoding_x = positional_encoding_x.repeat(batch_size, 1, 1)

  return positional_encoding_x

class Positional_embedding(nn.Module):
  # 원핫인코딩, 임베딩, 포지셔널 인코딩 한번에 처리
  def __init__(self, d_model, vocab_number):
    super(Positional_embedding, self).__init__()
    self.d_model = d_model
    self.vocab_number = vocab_number
    self.embedder = nn.Linear(vocab_number, d_model)

  def forward(self, x):
    one_hot_x = One_hot_encoding(x, self.vocab_number)
    embedding_x = self.embedder(one_hot_x)
    positional_encoidng_x = Positional_encoding(embedding_x)

    return embedding_x + positional_encoidng_x


def scaled_dot_product_attention(Q, K, V, mask, dropout):
  d_k = Q.size(-1)

  Kt = torch.transpose(K, -2, -1)
  QKt = torch.bmm(Q, Kt) # QKt : batch_size * sentence_length(Q) * sentence_length(K)
  masked_QKt = QKt.masked_fill(mask == 1, -1e9) # masking해야되는 값(pad)의 index는 True or False로 return할것이기 때문에 1로

  attention_score = masked_QKt/np.sqrt(d_k)
  attention_distribution = F.softmax(masked_QKt/np.sqrt(d_k), dim = -1)
  attention_distribution = dropout(attention_distribution)
  attention_value = torch.bmm(attention_distribution, V)

  return attention_value #  batch_size * sentence_length(Q) * d_v

class Single_head_attention(nn.Module):
  def __init__(self, d_model, d_k, d_v):
    super(Single_head_attention, self).__init__()
    self.linear_q = nn.Linear(d_model, d_k) # d_k = d_model / num_heads , num_heads는 동시 진행 어텐션 개수
    self.linear_k = nn.Linear(d_model, d_k)
    self.linear_v = nn.Linear(d_model, d_v)

  def forward(self, Q, K, V, mask, dropout):
    q = self.linear_q(Q)
    k = self.linear_k(K)
    v = self.linear_v(V)

    attention_value = scaled_dot_product_attention(q, k, v, mask, dropout)

    return attention_value  # batch_size * sentence_length * d_v

def module_copy(module, N): 
  # single_head_attention을 num_heads 만큼 복사해서 multi_head_attention 만들기
  return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Multi_head_attention(nn.Module):
  def __init__(self, d_model, d_k, d_v, num_heads, p = 0.1):
    super(Multi_head_attention, self).__init__()
    self.h = num_heads
    self.multiattention = module_copy(Single_head_attention(d_model, d_k, d_v), num_heads)
    self.linear = nn.Linear(num_heads * d_v, d_model)
    self.dropout = nn.Dropout(p)

  def forward(self, Q, K, V, mask):
    pre_cat_attention = []

    for i in range(self.h):
      pre_cat_attention.append(self.multiattention[i](Q, K, V, mask, self.dropout))

    post_cat_attention = torch.cat(pre_cat_attention, dim = -1)

    return self.linear(post_cat_attention)

class Encoder(nn.Module):
  def __init__(self, d_model, d_k, d_v, d_ff, h, p_drop = 0.1):
    super(Encoder, self).__init__()
    self.attention_layer = Multi_head_attention(d_model, d_k, d_v, h)
    self.dropout1 = nn.Dropout(p_drop)
    self.ln1 = nn.LayerNorm(d_model)

    self.feed_forward_layer = nn.Sequential(
                                    nn.Linear(d_model, d_ff),
                                    nn.ReLU(),
                                    nn.Dropout(p_drop),
                                    nn.Linear(d_ff, d_model))
    self.ln2 = nn.LayerNorm(d_model)
    self.dropout2 = nn.Dropout(p_drop)

  def forward(self, x, mask):
    x1 = self.attention_layer(x, x, x, mask)
    x2 = x + self.dropout1(x1) 
    x3 = self.ln1(x2)

    x4 = self.feed_forward_layer(x3)
    x5 = x3 + self.dropout2(x4)
    x6 = self.ln2(x5)
        
    return x6

def make_mask(src, trg, src_padding, trg_padding):
  src_n = src.size(1) # src_sentence_length
  trg_n = trg.size(1) # trg_sentence_length

  src_padding_mask = (src == src_padding).unsqueeze(1) # batch_size * 1 * src_sentence_length
  trg_padding_mask = (trg == trg_padding).unsqueeze(1) # batch_size * 1 * trg_sentence_length

  src_mask = src_padding_mask.repeat(1, src_n, 1) # src_pad인 부분을 QKt(self attention이니까 행,열 전부 src_sentence_length길이) 행만큼 늘리기
  memory_mask = src_padding_mask.repeat(1, trg_n, 1) # trg가 Q, src가 K 이므로 QKt는 batch_size * src_sentence_length * trg_sentence_length
  trg_mask = trg_padding_mask.repeat(1, trg_n, 1) # batch_size * trg_sentence_length * trg_sentence_length

  return src_mask, memory_mask, trg_mask

class Decoder(nn.Module):
  def __init__(self, d_model, d_k, d_v, d_ff, h, p_drop = 0.1):
    super(Decoder, self).__init__()
    self.self_attention_layer = Multi_head_attention(d_model, d_k, d_v, h)
    self.dropout1 = nn.Dropout(p_drop)
    self.ln1 = nn.LayerNorm(d_model)

    self.enc_dec_attention_layer = Multi_head_attention(d_model, d_k, d_v, h)
    self.dropout2 = nn.Dropout(p_drop)
    self.ln2 = nn.LayerNorm(d_model)

    self.feed_forward_layer = nn.Sequential(
                                nn.Linear(d_model, d_ff),
                                nn.ReLU(),
                                nn.Dropout(p_drop),
                                nn.Linear(d_ff, d_model))
    self.dropout3 = nn.Dropout(p_drop)
    self.ln3 = nn.LayerNorm(d_model)

  def forward(self, x, trg_mask, K, V, memory_mask):
    sentence_length = x.size(1)
        
    self_mask = np.triu(np.ones((1, sentence_length, sentence_length)), k=1) # k=1로 하면 (0,0)도 0으로. 첫 단어는 바로 참고할 수 있으니까
    self_mask = torch.BoolTensor((self_mask) == 1).cuda() # batch_size * sentence_length * sentence_length
        
    x1 = self.self_attention_layer(x, x, x, trg_mask | self_mask)
    x2 = x + self.dropout1(x1) 
    x3 = self.ln1(x2)

    x4 = self.enc_dec_attention_layer(x3, K, V, memory_mask)
    x5 = x3 + self.dropout2(x4) 
    x6 = self.ln2(x5)

    x7 = self.feed_forward_layer(x6)
    x8 = x6 + self.dropout3(x7)
    x9 = self.ln3(x8)

    return x9

class Transformer(nn.Module):
  def __init__(self, num_enc, num_dec, src_vocab_size, trg_vocab_size, d_model, d_k, d_v, d_ff, h):
    super(Transformer, self).__init__()
    self.num_enc = num_enc
    self.src_embedding = Positional_embedding(d_model, src_vocab_size)
    self.encoder = module_copy(Encoder(d_model, d_k, d_v, d_ff, h), num_enc)

    self.num_dec = num_dec
    self.trg_embedding = Positional_embedding(d_model, trg_vocab_size)
    self.decoder = module_copy(Decoder(d_model, d_k, d_v, d_ff, h), num_dec)

    self.linear = nn.Linear(d_model, trg_vocab_size)
        
  def forward(self, src, trg):
    src_mask, memory_mask, trg_mask = make_mask(src, trg, 2, 2) # pad_token = 2

    src = self.src_embedding(src)
    for i in range(self.num_enc):
        src = self.encoder[i](src, src_mask)
        
    trg = self.trg_embedding(trg)
    for i in range(self.num_dec):
        trg = self.decoder[i](trg, trg_mask, src, src, memory_mask)

    pred = self.linear(trg) # batch_size * sentence_length * trg_vocab_size, softmax를 통해 확률 높은 한 단어 선정

    return pred

# %%
import torch.nn.functional as F

from dataset.dataloader import load_data, get_loader
from dataset.field import Vocab
from utils import seq2sen

import time

# %%
def save_model(epoch, model, optimizer, loss, step_num, path):
    state = {
        'epoch' : epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': loss,
        'step_num' : step_num
        }
    
    torch.save(state, path)
    print('save complete : ' + path )

# %%
path = '/content/drive/MyDrive/모델 구현/1주차/transformer/multi30k'

# %%
# 일정 수(4) 이상 나온 단어들 묶음 + init, eos, pad, unk token을 합쳐서 단어꾸러미 만듦
# load는 이 만들어진 단어꾸러미의 단어에 각각 정수를 부여한 dict 자료형을 생성 

src, tgt = load_data(path)
src_vocab = Vocab(init_token='<sos>', eos_token='<eos>', pad_token='<pad>', unk_token='<unk>')
src_vocab.load(os.path.join(path, 'vocab.en'))
tgt_vocab = Vocab(init_token='<sos>', eos_token='<eos>', pad_token='<pad>', unk_token='<unk>')
tgt_vocab.load(os.path.join(path, 'vocab.de'))

# %%
sos_idx = 0
eos_idx = 1
pad_idx = 2
max_length = 50

num_enc = 6
num_dec = 6
d_model = 512
d_k = 64
d_v = 64
d_ff = 2048  # 피드 포워드 신경망 은닉층 차원
h = 8     # num_heads, 병렬로 어텐션을 수행할 때 병렬의 개수

# %%
# 원 핫 인코딩 차원수 결정
src_vocab_size = len(src_vocab)
tgt_vocab_size = len(tgt_vocab)

print(src_vocab_size)
print(tgt_vocab_size)
# Out:
# 3935
# 4376

# %%
# preprocessing, postprocessing, 단어 정수화, 배치화 등등 dataloader 기능 수행
# 이때, 문장 중 vocab에 있는 단어는 해당하는 정수가 부여되지만, 없는 단어는 unk_token (=3)이 붙음
train_loader = get_loader(src['train'], tgt['train'], src_vocab, tgt_vocab, batch_size=128, shuffle=True)
valid_loader = get_loader(src['valid'], tgt['valid'], src_vocab, tgt_vocab, batch_size=128)

# %%
device = torch.device("cuda" if(torch.cuda.is_available()) else "cpu")
transformer = Transformer(6, 6, src_vocab_size, tgt_vocab_size, d_model, d_k, d_v, d_ff, h).to(device)
optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

step_num = 1
warmup_steps = 4000
losses = []

# %%
for epoch in range(100):
  start_epoch = time.time()
  i = 0

  for src_batch, tgt_batch in train_loader:
    start_batch = time.time()

    src_batch = torch.tensor(src_batch).to(device) # 현재 상태는 batch_size x sentence_length, 단어가 dict value(정수)로 되어있음
    trg_batch = torch.tensor(tgt_batch).to(device)
                
    trg_input = trg_batch[:,:-1] # 마지막 단어는 input으로 들어가지 않으니까 
    trg_output = trg_batch[:,1:].contiguous().view(-1) # 처음 단어(sos_token)는 output으로 나오지 않으니까, F.crossentorpy를 위해 일자로 펴줌
                
    pred = transformer(src_batch, trg_input)

    # lr scheduling
    lr = (d_model ** -0.5) * min(step_num ** -0.5, step_num * (warmup_steps ** -1.5))
    for group in optimizer.param_groups: # optimizer.param_groups 에는 dict 형태로 각 항목별 parameter가 저장되어 있음
      group['lr'] = lr #학습률은 lr을 key로 저장되어 있으므로, 모든 가중치의 학습률을 해당값으로 고정위해 for문 사용

    optimizer.zero_grad()

    # F.cross_entropy 의 input은 (N,C)형태로, target은 (N)형태로
    loss = F.cross_entropy(pred.view(-1, pred.size(-1)), trg_output, ignore_index = 2) 
    loss.backward()

    optimizer.step()
    step_num += 1

    i = i+1
    losses.append(loss.item())

    batch_time = time.time() - start_batch
    print(f'[{epoch + 1}/{100}][{i}/{train_loader.size // 128 + 1}] train loss : {loss.item()} , duration : {batch_time}')
                
  
  # TODO: validation
  i = 0
  for src_batch, tgt_batch in valid_loader:
    start_batch = time.time()

    src_batch = torch.tensor(src_batch).to(device)
    trg_batch = torch.tensor(tgt_batch).to(device)
                
    trg_input = trg_batch[:,:-1]
    trg_output = trg_batch[:,1:].contiguous().view(-1)
                
    pred = transformer(src_batch, trg_input)
    loss = F.cross_entropy(pred.view(-1, pred.size(-1)), trg_output, ignore_index = 2)

    i = i + 1
    batch_time = time.time() - start_batch
    print(f'[{epoch+1}/{100}][{i}/{valid_loader.size//128 + 1}] valid loss : {loss.item()} , duration : {batch_time}')
            
  epoch_time = time.time() - start_epoch
  print(f'Time taken for {epoch + 1} epoch : {epoch_time}')

  save_model(epoch, transformer, optimizer, loss, step_num, f'checkpoints/epoch_{epoch+1}')

print('End of the training')
save_model(epoch, transformer, optimizer, loss, step_num, f'checkpoints/final')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# [27/100][67/227] train loss : 0.5082462430000305 , duration : 2.572721481323242
# [27/100][68/227] train loss : 0.5436937212944031 , duration : 2.0062477588653564
# [27/100][69/227] train loss : 0.5108552575111389 , duration : 2.019770622253418
# [27/100][70/227] train loss : 0.5435999631881714 , duration : 1.9947874546051025
# [27/100][71/227] train loss : 0.46190744638442993 , duration : 2.003833532333374
# %%
device = torch.device("cuda" if(torch.cuda.is_available()) else "cpu")
transformer = Transformer(6, 6, src_vocab_size, tgt_vocab_size, d_model, d_k, d_v, d_ff, h).to(device)
optimizer = torch.optim.Adam(transformer.parameters(), lr=0.0001, betas=(0.9, 0.98), eps=1e-9)

# %%
checkpoint = torch.load('checkpoints/epoch_94')
transformer.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']
step_num = checkpoint['step_num']

warmup_steps = 4000
losses = []

# %%
for epoch in range(94, 100):
  start_epoch = time.time()
  i = 0

  for src_batch, tgt_batch in train_loader:
    start_batch = time.time()

    src_batch = torch.tensor(src_batch).to(device) # 현재 상태는 batch_size x sentence_length, 단어가 dict value(정수)로 되어있음
    trg_batch = torch.tensor(tgt_batch).to(device)
                
    trg_input = trg_batch[:,:-1] # 마지막 단어는 input으로 들어가지 않으니까 
    trg_output = trg_batch[:,1:].contiguous().view(-1) # 처음 단어(sos_token)는 output으로 나오지 않으니까, F.crossentorpy를 위해 일자로 펴줌
                
    pred = transformer(src_batch, trg_input)

    # lr scheduling
    lr = (d_model ** -0.5) * min(step_num ** -0.5, step_num * (warmup_steps ** -1.5))
    for group in optimizer.param_groups: # optimizer.param_groups 에는 dict 형태로 각 항목별 parameter가 저장되어 있음
      group['lr'] = lr #학습률은 lr을 key로 저장되어 있으므로, 모든 가중치의 학습률을 해당값으로 고정위해 for문 사용

    optimizer.zero_grad()

    # F.cross_entropy 의 input은 (N,C)형태로, target은 (N)형태로
    loss = F.cross_entropy(pred.view(-1, pred.size(-1)), trg_output, ignore_index = 2) 
    loss.backward()

    optimizer.step()
    step_num += 1

    i = i+1
    losses.append(loss.item())

    batch_time = time.time() - start_batch
    print(f'[{epoch + 1}/{100}][{i}/{train_loader.size // 128 + 1}] train loss : {loss.item()} , duration : {batch_time}')
                
  
  # TODO: validation
  i = 0
  for src_batch, tgt_batch in valid_loader:
    start_batch = time.time()

    src_batch = torch.tensor(src_batch).to(device)
    trg_batch = torch.tensor(tgt_batch).to(device)
                
    trg_input = trg_batch[:,:-1]
    trg_output = trg_batch[:,1:].contiguous().view(-1)
                
    pred = transformer(src_batch, trg_input)
    loss = F.cross_entropy(pred.view(-1, pred.size(-1)), trg_output, ignore_index = 2)

    i = i + 1
    batch_time = time.time() - start_batch
    print(f'[{epoch+1}/{100}][{i}/{valid_loader.size//128 + 1}] valid loss : {loss.item()} , duration : {batch_time}')
            
  epoch_time = time.time() - start_epoch
  print(f'Time taken for {epoch + 1} epoch : {epoch_time}')

  save_model(epoch, transformer, optimizer, loss, step_num, f'checkpoints/epoch_{epoch+1}')

print('End of the training')
save_model(epoch, transformer, optimizer, loss, step_num, f'checkpoints/final')
# Out:
# [95/100][1/227] train loss : 0.04744343459606171 , duration : 2.071930170059204
# [95/100][2/227] train loss : 0.05429507791996002 , duration : 2.191410779953003
# [95/100][3/227] train loss : 0.06257300078868866 , duration : 2.4649291038513184
# [95/100][4/227] train loss : 0.04626242816448212 , duration : 2.1073529720306396
load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# %%
# test
test_loader = get_loader(src['test'], tgt['test'], src_vocab, tgt_vocab, batch_size=128)
pred = []
# TODO: predict pred_batch from src_batch with your model.
# every sentences in pred_batch should start with <sos> token (index: 0) and end with <eos> token (index: 1).
# every <pad> token (index: 2) should be located after <eos> token (index: 1).
# example of pred_batch:
# [[0, 5, 6, 7, 1],
#  [0, 4, 9, 1, 2],
#  [0, 6, 1, 2, 2]]

# %%
for src_batch, tgt_batch in test_loader:
  batch_size = len(tgt_batch)
  src_batch = torch.tensor(src_batch).to(device)
  pred_batch = torch.zeros(batch_size, 1, dtype = int).to(device) # [[0],[0],...,[0]]
  # eos_mask[i] = 1 means i-th sentence has eos
  eos_mask = torch.zeros(batch_size, dtype = int)

  for _ in range(max_length):
    output = transformer(src_batch, pred_batch) # batch_size * sentence_length * tgt_vocab_size
    output = torch.argmax(F.softmax(output, dim = -1), dim = -1) # batch_size * sentence_length , argmax로 최대값을 가진 인덱스를 리턴하여 해당 단어 정수 리턴
    predictions = output[:,-1].unsqueeze(1) # 예측 단어로 마지막 단어의 정수만 뽑아냄, pred_batch(sos_token 0)와 연결 위해 차원추가
    pred_batch = torch.cat([pred_batch, predictions], dim = -1) # pred_batch와 연결해서 디코더에 들어가는 새로운 pred_batch 생성

    for i in range(batch_size):
      if predictions[i] == eos_idx: # 문장의 마지막이 eos_idx이면, 0이던 값을 i번째는 1로 변환(끝난 문장을 알 수 있음)
        eos_mask[i] = 1 

    if eos_mask.sum() == batch_size :
      break # 모든 문장에서 eos가 나왔으므로 굳이 max_length까지 가지 않고 break
    
  pred += seq2sen(pred_batch.cpu().numpy().tolist(), tgt_vocab) # tensor를 list형태로 변환하고 정수 인덱스를 단어로 변환

# %%
pred
# Out:
# ['Ein Mann mit orangefarbener Mütze starrt auf etwas .',
#  'Ein Fan rennt auf <unk> grünem Gras vor einem weißen Zaun .',
#  'Ein Mädchen in <unk> , das einen Stock trägt , mit einem <unk> .',
#  'Fünf Menschen mit <unk> und Helm stehen im Schnee , <unk> im Hintergrund',
#  'Leute befinden sich auf dem Dach eines Hauses .',
#  'Ein Mann in hellen Kleidern fotografiert eine Gruppe Männer mit dunkler Kleidung und Hüten steht um eine Frau mit einem <unk> @-@ Frisur .',
#  'Eine Gruppe von Menschen steht vor einem <unk> .',
#  'Ein Junge in einer roten Uniform versucht , beim <unk> im blauen Trikot einen , während der Fänger im blauen Trikot zu berühren .',
#  'Ein Typ arbeitet an einem Gebäude .',
#  'Ein Mann in einer Weste sitzt auf einem Stuhl und hält Zeitschriften .',
#  'Eine Mutter und ihr kleine Orchester genießen im Freien ein schöner Tag .',
#  'Männer spielen Volleyball , während ein <unk> <unk> in die Höhe hält , sodass er in der Luft ist .',
#  'Eine Frau hält eine Schüssel Essen in einer Küche .',
#  'Ein Mann sitzt an einem Tisch im Haus und trägt ein <unk> .',
#  'Drei Menschen sitzen in einer Höhle .',
#  'Ein Mädchen in einem <unk> @-@ Kleid geht einen <unk> entlang .',
#  'Ein blonder Typ hält einen Mann im Sand .',
#  'Eine Frau in einem grauen Pullover und mit schwarzer Baseballkappe steht in einer Linie .',
#  'Die Person im gestreiften Hemd klettert einen Berg hoch .',
#  'Zwei Männer albern <unk> , während eine Frau ihnen <unk> .',
#  'Menschen stehen vor einem Gebäude .',
#  'Ein Teenager spielt konzentriert auf dem Feld bei einem Spiel auf .',
#  'Eine Frau macht auf einem Trampolin eine <unk> .',
#  'Ein Mann steht neben einer Gruppe von <unk> in einer Bar .',
#  'Eine Frau verwendet eine <unk> , während ein anderer Mann fotografiert .',
#  'Eine Frau in einem rosa Pullover und mit einer Schürze reinigt einen Tisch mit einem <unk> .',
#  'Ein Mann schneidet <unk> mit <unk> .',
#  'Eine Gruppe asiatischer Jungen wartet darauf , dass Fleisch über das <unk> <unk> .',
#  'Eine Frau in traditioneller Kleidung <unk> <unk> .',
#  'Ein Mann hält seinen Kopf eines anderen Mannes und bereitet sich darauf vor , im Gesicht zu schlagen .',
#  'Sechs Personen fahren auf <unk> durch einen <unk> .',
#  'Zwei blonde Mädchen sitzen auf einem <unk> Platz .',
#  'Ein Kind planscht im Wasser .',
#  'Drei Personen sitzen an einem Picknicktisch vor einem Gebäude , das wie ein <unk> <unk> aussieht .',
#  'Drei Jungen stehen auf einer Anlegestelle in ihren <unk> .',
#  'Ein <unk> gibt einer Frau auf einem Straßenmarkt , während sie durch einen Fisch auf einem Straßenmarkt .',
#  'Eine hübsche Frau spielt <unk> .',
#  'Ein <unk> , uniformierter , mit einem Hut blickt von einem Zaun weg in die Kamera .',
#  'Die junge Frau betrachtet die Pizza .',
#  'Ein Mann mit freiem Oberkörper in kurzen Hosen steht auf einigen Felsen .',
#  'Ein Mädchen mit einer Rettungsweste schwimmt im Wasser .',
#  'Ein Mann in Uniform und ein Mann in einem blauen Hemd stehen vor einem Lastwagen .',
#  'Menschen sitzen in einem Zug .',
#  'Ein Kind schaukelt mit den Füßen in einem Wald hoch .',
#  'Ein Mann in rotem Hemd gießt in eine <unk> .',
#  'Zwei Männer mit Badehose springen an einem Strand in die Luft .',
#  'Ein Kleinkind kocht mit einer anderen Person .',
#  'Ein Vater mit zwei Kindern und zwei Kindern im Freien beim <unk> von ihrem Haus mit einem <unk> und einem <unk> .',
#  'Ein Mann kocht Essen auf dem Herd .',
#  'Ein Mann in Jeans am Strand spielt mit einem roten Ball .',
#  'Menschen gehen auf dem Bürgersteig an einer Reihe Einkäufer entlang .',
#  'Ein <unk> vollführt einen Salto bei großen schnell auf seinem <unk> .',
#  'Eine große Gruppe von Menschen redet auf einer Straße .',
#  'Ein Mann auf einem Floß springt ins Wasser .',
#  'Eine Frau in Jeans geht an einem Bus vorbei , während eine Frau eine Sonnenbrille über eine Sonnenbrille aussieht .',
#  'Ein Mann in einem rosa Hemd sitzt im Gras und ein Ball ist in der Luft .',
#  'Ein Auto , das am Strand geparkt ist .',
#  'Zwei Männer schwarz tragen schwarze Bekleidung .',
#  'Der Mann in der gelben Hose hebt seine Arme .',
#  'Zwei Männer mit Hüten und <unk> gehen zu Fuß in der Nähe eines Gewässers entlang .',
#  'Ein Cheerleader @-@ Team macht eine <unk> auf Stühlen .',
#  'Ein Junge spielt mit einem Erwachsenen auf dem Bildschirm , während ein Mädchen zusieht .',
#  'Eine Menschenmenge , die sich beim <unk> in einem öffentlichen Park gut <unk> .',
#  'Ein Mann sitzt mit seinem Hund auf einer Bank und hält seinen Hund in der Hand .',
#  'Ein Junge und sein kleiner Bruder , die zusammen auf dem Spielplatz spielen .',
#  'Eine Frau in Blau schaut auf eine schwarze <unk> , während sie auf einem sonnigen <unk> sitzt und hinter ihr sind .',
#  'Der brauen Hund steht auf dem Sandstrand .',
#  'Eine Frau sitzt mit einem Korb , umgeben von <unk> , .',
#  'Ein Mann , der im Hinterhof grillen .',
#  'Eine Frau singt in einem Club , hinter ihr steht ein Gitarrist .',
#  'Ein <unk> schlägt mit einer <unk> @-@ Gitarre .',
#  'Ein Kind sitzt auf einem Rasen und blickt auf die Kamera .',
#  'Zwei Damen und drei Männer schauen ins Meer .',
#  'Eine <unk> mit einer <unk> spielt auf einer Straße , während eine Frau mit blauer Gitarre zusieht .',
#  'Ein kleines Mädchen schwimmt in einem Pool .',
#  'Mehrere Kinder befinden sich im Freien und machen sich bereit , im Hintergrund <unk> .',
#  'Drei Teenager in einer U @-@ Bahn spielen .',
#  'Ein brauner Hund läuft mit heraushängender Zunge im Gras .',
#  'Menschen sitzen im Gras an einem Gebäude und machen eine Pause .',
#  '<unk> einer Frau <unk> , die von einer Menschenmenge sitzt , während sie in eine Sonne vorbeigehen .',
#  'Zwei kleine Jungen machen Obst auf dem Fahrrad .',
#  'Ein Mann in einem schwarzen T @-@ Shirt , Mütze und Jeans spielt auf einem kopfüber .',
#  'Ein junge <unk> malt ein Bild einer Frau auf einer Mauer .',
#  'Zwei <unk> @-@ <unk> führen eine <unk> vor zwei anderen Personen einen Sprung vor .',
#  'Ein Mann in einer Küche rührt einen Topf von einer Flüssigkeit .',
#  'Der Junge springt im See .',
#  'Ein Mann arbeitet an einem Hotdog .',
#  'Eine große Gruppe von mehreren Personen mit verschiedenen Garn und <unk> sitzt im Freien .',
#  'Eine blonde Frau trinkt in einer Bar Getränke .',
#  'Ein kleines Kind mit einem blau @-@ weißen T @-@ Shirt hält glücklich in ein gelbes <unk> .',
#  'Eine Frau mit rosa Haaren und schwarz gekleideter Mann redet mit einem Mann .',
#  'Der Mann in einem japanischen Anzug bereitet vor zwei Personen einen Vortrag vor .',
#  'Ein Mädchen springt über den Fluss aus einem Felsen .',
#  'Ein Arbeiter mit einem <unk> kniet neben zwei Frauen .',
#  'Ein älterer Mann öffnet Armen seine Arme und sieht <unk> .',
#  'Ein Kind in einem weißen Karateanzug macht eine Bewegung .',
#  'Drei Männer in <unk> orangefarbenen Westen sind im Freien .',
#  'Eine Frau mit einem rosafarbenen Hut macht ein Foto von einem Baby , während sie trägt .',
#  'Eine Gruppe <unk> asiatischer Kinder sitzt auf blauen Stühlen im Sitzen .',
#  'Ein kleiner Junge in einem Fußballtrikot weint in seinen <unk> .',
#  'Eine schöne Frau bereitet in einem Café eine <unk> vor .',
#  'Ein Bauarbeiter legt schwere Ausrüstung auf einer Baustelle .',
#  'Eine Frau rennt mit einem <unk> nach vorne gebeugt , der den <unk> <unk> .',
#  'Ein Mann in Arbeitskleidung fährt an einem Werkzeug vorbei , um eine andere Person zu sprechen .',
#  'Eine Gruppe von Menschen klettert bei kalten Wetter in <unk> Wetter .',
#  'Ein <unk> , der gleich mit einem blauen Helm einen Berg <unk> hat .',
#  'Ein Mann macht Handstand auf einer runden Statue .',
#  'Ein Kind sitzt an einem Restaurant und hält eine <unk> an seinem Gesicht .',
#  'Ein brauner Hund hält sich in einen See , um einen Stock zu richten .',
#  'Eine Mutter <unk> ihren zwei Jungen , um von einer <unk> in sehr blauen Wasser zu fischen .',
#  'Ein kleines Kind geht neben roten <unk> .',
#  'Ein Mädchen sitzt auf einem dekorierten Fahrrad mit einem älteren Jungen , während ein anderes Mädchen fotografiert .',
#  'Ein schwarzer Hund springt in Wasser .',
#  'Ein Mann in einer weißen Hose und einem blauen Hemd tritt einen gelben <unk> .',
#  'Zwei <unk> Männer , die an einer Zeremonie teilnehmen .',
#  'Ein Junge mit <unk> @-@ <unk> @-@ <unk> und schreibt auf seine Hände in einem <unk> .',
#  'Zwei <unk> Personen paddeln bei Sonnenuntergang auf dem Meer .',
#  'Menschen stehen auf einer überfüllten U @-@ Bahn und der Bus ist im Freien durch das Fenster .',
#  'Ein Mann , der an einer Wand mit Feuer in der Hand geht',
#  'Zwei braune Hunde laufen durch den Schnee .',
#  'Ein <unk> führt vor einem <unk> Publikum auf .',
#  'Ein Baby in einem <unk> Outfit schaut in die Kamera .',
#  'Ein Mann sitzt neben einem Computerbildschirm .',
#  'Diese Dame hat einen <unk> <unk> und lacht .',
#  'Leute in einem Gebäude , einer davon macht ein Foto .',
#  'Vier weiße Hunde mit Maulkörben springen über eine rote Mauer .',
#  'Die Frau mit dem blauen Oberteil hält ein Baby .',
#  'Zwei Personen sitzen auf gestreiften <unk> auf einem Gewässer .',
#  'Eine alte Frau arbeitet an einem Webstuhl und stellt <unk> her .',
#  'Ein Junge , der auf einem Platz sitzt , guckt sich über anderen Menschen in einem Hof .',
#  'Ein Mann in einem blauen Mantel streckt die Hand eines kleinen Jungen .',
#  'Drei brauen Hunde springen nach einer Frau in blau .',
#  'Ein Junge hängt an einem <unk> <unk> .',
#  'Ein Mann in einem grauen Hemd springt über die <unk> einer Sanddüne in der Wüste .',
#  'Ein Kind , das ein gelbes Hemd trägt , springt hoch und runter .',
#  'Ein Arbeiter in einer gelben Jacke <unk> hoch oben an einem Gebäude .',
#  'Ein Mann in einem <unk> unterhält sich vor einer <unk> .',
#  'Ein paar <unk> ziehen <unk> an eine Bar mit <unk> .',
#  'Ein Mann <unk> eine Klippe über dem Meer hinunter .',
#  'Ein schwarz gekleideter Mann schiebt im Schnee seinen LKW an .',
#  'Ein <unk> springt nach einem Ball .',
#  'Eine <unk> mit <unk> und <unk> lächelt , während sie vor einem Geschäft mit Sonnenbrille trägt .',
#  'Eine Krankenschwester geht zu Fuß in einem Park .',
#  'Ein Mann mit einem grünen Schutzhelm und mit gelber Sicherheitsweste <unk> .',
#  'Ein Kind mit einer rosafarbenen Maske tanzt inmitten in <unk> , <unk>',
#  'Ein Hund mit einer Nummer Nase @-@ <unk> an etwas , der an einem Flussufer ist .',
#  'Ein Mann bereitet seinen <unk> im <unk> @-@ <unk> .',
#  'Ein Mann in rotem Hemd beißt gleich wie ein <unk> .',
#  'Eine weiß gekleidete junge Frau hält einen Tennisschläger .',
#  'Ein Junge in rotem Hemd gräbt mit einer gelben Schaufel in den Sand .',
#  'Eine Person mit <unk> Jacke fährt auf einer Holzbank auf .',
#  'Ein Mann in einem weißen Hemd schaut aus dem Fenster eines <unk> .',
#  'Eine Frau hält ein kleines weißes Statue .',
#  'Sechs Kinder mit freiem Oberkörper spielen in <unk> Wasser und spielen in <unk> .',
#  'Zwei Personen fahren auf Rädern durch eine <unk> .',
#  'Ein Mädchen das auf dem Gehweg in einer <unk> auf dem Bürgersteig springt .',
#  'Ein Mann in orangefarbenem Hemd und mit Helm .',
#  'Ein kleiner Junge spielt mit <unk> , Autos und einem Erwachsener , die sehr andere Personen abgebildet sind .',
#  'Ein kleines Mädchen öffnet ein <unk> Geschenk .',
#  'Die Frau in blauer Kleidung bedient eine Kamera vor zwei anderen Frauen .',
#  'Ein kleines Mädchen versucht auf dem <unk> @-@ Sofa zu machen .',
#  'Ein braun @-@ schwarzer Hund , springt im Wald auf einem Pfad .',
#  'Zwei Hunde spielen bei einem Baum .',
#  'Ein <unk> , der einen schwarzen Mantel und Hosen trägt , geht auf die Stufen , während er <unk> auf dem Hund <unk> .',
#  'Zwei Männer in grüner Kleidung bereiten Essen in einem Restaurant zu .',
#  'Ein schwarz gekleideter Mann mit einem Cowboyhut um ein <unk> @-@ <unk> herum .',
#  'Ein Hund rennt im Freien mit einem gelben Spielzeug .',
#  'Ein Hund mit einer Geldbörse läuft durch den Schnee .',
#  'Eine Familie spielt am Strand mit ihrem Hund .',
#  'Eine Frau und ein Kind umarmen sich , während sie ein Kind <unk> hat .',
#  'Zwei Männer und eine Dame stehen draußen .',
#  'Eine Gruppe Männer schiebt <unk> , um ein Boot aus dem Wasser zu schieben .',
#  'Ein Mann trinkt an einem <unk> und liest Zeitung .',
#  'Ein Mann in einem schwarzen , schwarzen und spielt auf einem Klavier .',
#  'Ein kleiner Junge in einem blauen Trikot und gelben Shorts spielt Fußball .',
#  'Ein Mann steht auf einer <unk> mit <unk> Armen auf einem Vogel .',
#  'Ein Hund wird im Freien auf dem Gras .',
#  'Zwei Frauen in <unk> schauen in die Kamera .',
#  'Ein Mann sitzt auf dem <unk> , um einer Hochzeit zu <unk> .',
#  'Ein kleines , mit grünen Stiefeln , spielt in einer <unk> .',
#  'Ein Mann schneidet mit einer Kettensäge eine Kettensäge .',
#  'Ein Mann sitzt an einem Picknicktisch mit einem essen und einem <unk> <unk> Mann vor ihm .',
#  'Der Junge , der ein schwarzes Hemd und blaue Jeans trägt , hält einen roten Schläger .',
#  'Ein dunkelhaariger Mann mit Brille und einem <unk> sitzt auf dem Rasen .',
#  'Hunde laufen auf einer <unk> .',
#  'Ein hellhäutiger Mann mit <unk> Nase schneidet einen Herrn über einen Balkon .',
#  'Zwei <unk> <unk> sich gegenseitig .',
#  'Eine Gruppe von Menschen steht auf einer Art Veranstaltung herum .',
#  'Ein braun @-@ weißer Hund holt sich um ein Spielzeug .',
#  'Ein Mann mit weißem Haar , der mitten zwischen ein <unk> spielt .',
#  'Eine Frau mit braunem Haar sitzt draußen auf einer Bank vor einem Café .',
#  'Ein Mann neben einem Fahrrad spielt Flöte .',
#  'Zwei Kinder balancieren auf einem <unk> und halten ein Seil .',
#  'Ein Mann auf einem Motorrad führt ein Kunststück auf einem Bahn vor .',
#  'Eine junge Frau mit einem violetten Tuch im Gesicht , die auf einem <unk> <unk> .',
#  'Die Frau im braunen Oberteil sitzt auf einer leuchtend roten Bank .',
#  'Ein Hund läuft über einen <unk> Fluss .',
#  'Ein junger Mann mit weißem T @-@ Shirt und grün @-@ schwarzer Hose steht auf einem Motorrad .',
#  'Eine Gruppe von Menschen , die alle mit Regenschirmen bedeckt sind .',
#  'Ein Mann <unk> ein <unk> Schild , das an seinem Fahrrad festgebunden ist .',
#  'Ein Mann wirft einen <unk> in eine Wasserstraße , während zwei Hunde zusehen .',
#  'Gruppe von <unk> spielt unter einem <unk> am Wasser auf Instrumenten .',
#  'Eine Ansicht einer überfüllten Straße .',
#  'Eine junge blonde Frau hält an einem sonnigen Tag eine weiße Scheibe .',
#  'Zwei Menschen in blauen Hemden sind im Freien mit einem <unk> .',
#  'Ein schwarzer Hund springt in einen Pool .',
#  'Ein Cowboy auf dem Rücken eines <unk> bei einem Wettbewerb .',
#  'Eine <unk> bei <unk> <unk> auf Bahngleisen .',
#  'Ein Arbeiter in orangefarbener Weste benutzt eine Schaufel .',
#  'Zwei Bauarbeiter unterhalten sich auf einer Baustelle .',
#  'Drei Männer laufen auf <unk> .',
#  'Eine asiatische Frau in einem Bikini @-@ Hochzeitskleid posiert auf einer Brücke an ihren Tischen .',
#  'Ein junger Mann <unk> in der Küche seiner Gitarre .',
#  'Drei Jungen spielen mit <unk> und Eimern mit <unk> .',
#  'Drei Bauarbeiter <unk> den Boden .',
#  'Menschen im Wald neben Kanus .',
#  'Ein Chor in einer Kirche hat sich gemeinsam versammelt .',
#  'Eine Gruppe junger Teenager springt nachts in die Kamera und macht eine große Pose für die Kamera .',
#  'Zwei Männer fahren Kajak , einer von ihnen ist ein blauer <unk> .',
#  'Zwei Arbeiter haben <unk> an einem <unk> .',
#  'Eine Dame in einem <unk> Pullover und Jeans sitzt auf dem linken Knie .',
#  'Zwei Künstler geben einen <unk> für ein Publikum , das aufmerksam Publikum zusehen .',
#  'Ein <unk> Bus und wartet auf einen Flughafen .',
#  'Ein Mann in einem gelben Mantel <unk> einen Jungen im <unk> , während ein Junge in einem <unk> zugucken .',
#  'Ein Mann und ein Junge auf einem steinigen Strand .',
#  'Eine Frau auf einem Boot namens „ <unk> “ -Schild <unk> bis ins Wasser .',
#  'Ein Junge sitzt auf einem Stuhl und schaut durch ein Mikroskop .',
#  'Ein junges barfüßiges Mädchen in einem rosa Kleid springt im Freien .',
#  'Viele Leute sitzen im Freien um ein Zelt herum .',
#  'Ein Jugendlicher in einem schwarzen Hemd mit der Aufschrift „ <unk> <unk> <unk> “ spielt Klavier .',
#  'Ein Mann verkauft auf dem Gehweg an einem hohen Berg Sachen .',
#  'Das Mädchen in Gelb lacht dem rosa gekleideten Mädchen in Blau beim <unk> von <unk> an .',
#  'Ein Hund springt im Freien über ein Hindernis .',
#  'Ein Hund mit schwarzem Halsband läuft im Dreck umher und <unk> .',
#  'Zwei braune Hunde , die in einem <unk> <unk> spielen .',
#  'Ein Mann mit Schnurrbart und Bart hält eine Pfanne , die von ihm <unk> gesehen hat .',
#  'Ein Mann in <unk> Kleidung trägt ein <unk> @-@ <unk> @-@ <unk> .',
#  'Ein Mann in schwarzem Hemd , der an einem steinigen Ufer angelt .',
#  'Zwei Hunde <unk> sich gegenseitig <unk> .',
#  'Zwei Männer unterhalten sich auf dem Gehweg , während ein Auto vorbeifährt .',
#  'Ein <unk> Mann wartet auf Kunden .',
#  '<unk> hinter ihnen in einem Schulbus .',
#  'Zwei Frauen , die <unk> Hemden tragen , gehen über die linken .',
#  'Ein kleines Kind mit einer orangefarbenen Schwimmweste hält in einem blauen Kajak , das einen blauen Kajak im Wasser paddelt .',
#  'Menschen gehen auf einem Weg in einem von vielen <unk> .',
#  'Drei junge Frauen unterhalten sich in einer Menschenmenge und die Frau schaut hinein .',
#  'Eine Frau und ein Kind vor ihrer Tür im Freien .',
#  'Ein dunkelhäutiger Mann und seine zwei weiße Freunde <unk> im Freien weg .',
#  'Ein Mädchen in <unk> sitzt auf einem <unk> .',
#  'Ein hellbrauner Hund rennt .',
#  'Ein Junge posiert mit einer großen grünen <unk> auf der Nase .',
#  'Ein kahlköpfiger Mann springt so kann , sein braun @-@ schwarzen Hund beim Sprung von seinem Fell , nach .',
#  'Eine Menschenmenge auf einer belebten <unk> .',
#  'Ein Windhund mit Maulkorb und schwarz bekleidet läuft auf der Strecke .',
#  'Ein Mann mit Sandalen sitzt auf dem Gehweg in der Nähe von einigen Taschen .',
#  'Ein Mann und eine Frau sitzen am Kai eines <unk> und unterhalten sich .',
#  'Ein Kind sieht sich eine Zigarette an .',
#  'Ein Mann trinkt bei einer belebten Veranstaltung um eine große Anzahl von Leuten .',
#  'Ein Junge lehnt gegen ein Auto mit Blumen auf einer Motorhaube .',
#  'Eine Frau in einem geblümten Kleid redet vor Kindern in einem Kai .',
#  'Ein Mann an seinem Tag .',
#  'Eine junge Frau mit schwarzem Oberteil und Jeans fegt .',
#  'Eine Frau mit einem Hut auf dem , die an einer großen Wasserfläche steht .',
#  'Ein großer schwarzer Pudel mit einem Spielzeug im Maul läuft über das Gras .',
#  'Ein Junge in kurzen Hosen macht ein Kunststück mit dem Skateboard .',
#  'Ein kleiner Junge mit roten Hosen steht auf der Straße .',
#  'Eine Frau schreibt etwas auf ihrem Telefon , während sie von Schirmen umgeben ist .',
#  'Acht Männer spielen auf der Bühne auf Instrumenten , während ein Gitarrist im <unk> <unk> <unk> sind .',
#  'Ein Mann in einem orangefarbenen Overall und mit <unk> Baseballkappe hilft mit einem blauen Schlauch .',
#  'Ein Mann und zwei Mädchen <unk> einen Fisch von einem Computer weg und halten <unk> vor einem Gewässer .',
#  'Ein Mann in einem roten Oberteil sieht zu , wie er auf einem <unk> <unk> , zu .',
#  'Ein Junge in einer violett @-@ weißen Badehose springt zurück in ein <unk> Schwimmbecken .',
#  'Eine Asiatin <unk> ihr Haar nach hinten .',
#  'Eine ältere Frau und ein kleines Kind in pinkfarbenem Hemd spielen mit bunten <unk> .',
#  'Ein kleiner schwarzer Hund springt über <unk> .',
#  'Ein braunhaariger Mann in einem grünen Hemd spielt im Freien Trompete .',
#  'Ein Mann telefoniert mit <unk> Beinen .',
#  'Eine Gruppe von Kindern sitzt auf einer blauen Matte und isst <unk> aus Büschen .',
#  'Ein schwarzer Junge sitzt im Sand .',
#  'Ein kleiner Hund beobachtet zwei große Hunde , der <unk> auf einem Feld spielt .',
#  'Menschen sitzen draußen in einem Kreis vor einem großen Gebäude .',
#  'Ein Hund springt hoch , während ein anderer ihnen zusieht .',
#  'Ein blondes Kind schaukelt auf einer Schaukel .',
#  'Ein Mann und zwei Frauen diskutieren eine weiße <unk> .',
#  'Ein asiatischer Mann grillt im Freien Essen .',
#  'Ein brauner Hund , der gleich eine grüne Frisbee @-@ Frisbee hinterher zu fangen .',
#  'Ein <unk> <unk> , als die Band ein Lied spielt .',
#  'Ein kleiner Junge steht an einer Sandskulptur von einer <unk> .',
#  'Drei kleine Kinder gehen über einen grasbewachsenen Hof .',
#  'Ein Mann entspannt auf einem <unk> .',
#  'Ein Mann auf einem Fahrrad fährt auf einem Berg .',
#  'Ein Junge mit blauen und gelben <unk> rennt auf einem Parcours .',
#  'Eine Frau in einer orangefarbenen Jacke sitzt auf einer Bank .',
#  'Ein Mann macht ein Kunststück auf dem Skateboard .',
#  'Ein Mann in einem <unk> befindet sich in der Luft .',
#  'Frauen verkaufen auf dem Gehweg Sachen .',
#  'Zwei Fußballmannschaften befinden sich auf dem Spielfeld .',
#  'Ein Kind in blauem Hemd springt von einer Bank .',
#  'Ein Torhüter auf einem gelben Feld <unk> das Tor .',
#  'Eine Gruppe junger Leute nimmt <unk> in einem <unk> <unk> .',
#  'Ein junger Mann fährt mit dem Skateboard von einem rosa Geländer .',
#  'Ein kleiner Junge springt von einem <unk> Bett auf einem kleineren Bett ab .',
#  'Zwei Personen in <unk> Uniformen , eine blau und eine blau gekleidete Menschen steht auf einer Straße .',
#  'Ein Mann mit blauem Hemd und einer Nummer <unk> .',
#  'Ein Asiate posiert vor der Kamera .',
#  'Ein Mann scheint beim Laufen den Ball <unk> .',
#  'Basketballspieler ziehen bei einem Spiel ein Tor .',
#  'Ein Footballspieler in einer orangefarbenen Uniform hält lächelnd in der Hand und hält das Fußball .',
#  'Zwei <unk> tragen eine Kurve , während andere zusehen .',
#  'Ein weiß gekleideter Team ist auf der Seite eines <unk> .',
#  'Ein kleines Mädchen schiebt ihren Roller durch einen grasbewachsenen Ast mit Gras .',
#  'Eine Gruppe von asiatischen Kindern in weißen Oberteilen und Hüten tritt mit einer Menschenmenge auf .',
#  'Fußgänger gehen die Straße hinunter und blicken auf ein Kind in einer <unk> .',
#  'Ein brauner Hund rennt den Sandstrand herum .',
#  'Zwei Männer in <unk> stehen neben einer Frau .',
#  'Die <unk> bei einer <unk> <unk> <unk> <unk> , bei der <unk> <unk> <unk> werden .',
#  'Ein Fahrradfahrer springt über ein Hindernis .',
#  'Ein Paar sitzt auf weißen <unk> und lacht in die Kamera .',
#  'Kleine Kinder sind auf einem kleinen Zug .',
#  'Ein Surfer in einem blauen Badeanzug reitet auf den Wellen .',
#  'Der Junge springt auf seinen hellbraunen Teppich .',
#  'Zwei junge Männer auf gegnerischen <unk> kämpfen um den Ball auf einem Fußballfeld zu lassen .',
#  'Leute laufen auf einem von chinesischen Weg umgeben , umgeben von chinesischen Tischen .',
#  'Ein kleiner Junge in einer weißen Hose springt von der Couch .',
#  'Ein Junge in einem orangen Hemd schüttet <unk> aus einer Tasche .',
#  'Eine Frau mit braunen Socken , blauen Jeans und blauer Jeans hält ein Kalb unter einem großen Baum .',
#  'Drei Personen tragen und halten eine <unk> .',
#  'Ein Polizist steht neben einem Auto auf einer städtischen Straße .',
#  'Zwei Männer , die <unk> tragen , sitzen .',
#  'Ein Junge in der Luft versucht , einen Fußball zu kicken .',
#  'Ein kleiner Junge mit blauer Mütze hat seinen Kopf den Kopf herunter .',
#  'Ein rothaariger Mann mit Dreadlocks und Dreadlocks spielt und <unk> .',
#  'Ein Mann , der ein Sandwich isst und mit seiner <unk> im Schoß ist .',
#  'Ein afroamerikanisches Kind hält etwas , das in Hand macht , vom Bild <unk> ist .',
#  'Eine Frau <unk> eine Menschenmenge mit einem <unk> .',
#  '<unk> Zuschauer sehen zu , wie ein Mann im Anzug eine Rede macht und ein Mann im Anzug eine Schüssel mit Obst <unk> .',
#  'Eine Menschenmenge hört etwas in einer Bar .',
#  'Ein Mädchen in einem weißen und ein Mädchen in Grün gehen an einem blauen Auto vorbei .',
#  'Ein Mann verwendet elektronischen Geräten .',
#  'Ein Mensch surft im Meer durch eine <unk> Welle .',
#  'Ein <unk> untersucht etwas .',
#  'Braut und Bräutigam küssen sich unter der <unk> .',
#  '<unk> stehen im Hintergrund , während im Hintergrund ein junger Mann mit einem roten Schal mit rotem Schal <unk> .',
#  'Ein schwarz @-@ weißer Hund springt bei einem Wettbewerb über eine <unk> .',
#  'Eine Frau im Pullover liest ein Buch in ihrem Haus .',
#  'Mehrere Teenager in einem dunklen Raum schauen über ein Geländer .',
#  'Der Mann im weißen T @-@ Shirt geht an einem Felsen .',
#  'Ein Teenager streckt in der Küche und <unk> <unk> sich dabei an den <unk> .',
#  'Menschen halten verschiedenen <unk> über verschiedenen <unk> .',
#  'Drei <unk> <unk> auf einem <unk> Feld aus freiem Himmel .',
#  'Zwei Frauen und ein Mann schauen ein Buch an .',
#  'Drei Kinder werden von den Beinen gezeigt , während sie in der Nähe eines <unk> stehen .',
#  'Ein Koch posiert für eine Kamera und kocht .',
#  'Viele Leute in einer Straße , die den <unk> in einer älteren <unk> .',
#  'Der Teenager springt mit seinem Fahrrad über den Hügel .',
#  'Ein kleines Mädchen läuft am Strand am Strand .',
#  '<unk> <unk> im Wasser <unk> .',
#  'Zwei Männer unterhalten sich , während sie vor einem <unk> stehen , und hinter ihnen aussieht ein <unk> , während viele Personen herumstehen .',
#  'Eine Frau in einem rosa Rock hält ein Baby .',
#  'Ein Hockeyspieler in einem gelben Trikot <unk> das Tor .',
#  'Ein Mann geht an einem großen Schild mit der Aufschrift „ großen <unk> “ vorbei .',
#  'Drei Jungen in grünen Hemden und hellbraunen Hosen posieren auf einer Rutsche .',
#  'Ein Mann tanzt mit einem Hund und zwischen seinen Beinen .',
#  'Der weiße Hund rennt im seichten Wasser .',
#  'Ein <unk> marschiert mit der Band .',
#  'Eine Gruppe von Kindern spielt zusammen auf einem eingezäunten Hof , während ein Erwachsener zuschaut .',
#  'Eine Gruppe Frauen spielt zusammen auf Musikinstrumenten .',
#  'Ein kleines Mädchen in einem lila karierten Kleid liegt auf dem Boden .',
#  'Ein Mann mit <unk> Haar schneidet seine <unk> auf .',
#  'Zwei schwarze Hunde , ein schwarzer Welpe und ein weißer Hund ist im Schnee .',
#  'Ein Mann in Miami @-@ Basketball springt um einen Wurf zu machen .',
#  'Eine Frau sitzt draußen an ihrem Haus mit einer blauen Tür und genießt die Luft .',
#  'Kinder sitzen auf einem Mann in einem mit <unk> orangefarbenen Anzug .',
#  'Ein grau @-@ weißer Hund , der über Wasser im Sand steht .',
#  'Eine Menschenmenge ist im Regen um eine <unk> versammelt .',
#  'Mehrere ältere Männer mit traditioneller Kopfschmuck auf einer Straßenecke .',
#  'Ein junger <unk> Hund ist im Schnee .',
#  'Der Fußballspieler im goldenen Trikot <unk> den Ball der gegnerischen Mannschaft den Ball nach .',
#  'Eine Frau in einem schwarzen Oberteil strickt mit einem lilafarbenen Garn .',
#  'Vier Frauen asiatischer Herkunft tragen <unk> und führen eine <unk> .',
#  'Eine Person spielt ein <unk> Instrument .',
#  'Ein Mädchen in schwarzer Sportkleidung mit der Nummer <unk> auf ihrem <unk> fährt über das Gras .',
#  'Ein Kind , der bei „ <unk> “ @-@ <unk> @-@ “ Pferde trägt , mischt <unk> .',
#  'Ein älterer Herr und ein junges Mädchen arbeiten zusammen an einem <unk> .',
#  'Ein <unk> führt einen kleinen afrikanischen Jungen in gelbem Hemd an .',
#  'Eine <unk> Brücke mit einem Radfahrer Radfahrer und einigen Autos .',
#  'Ein Mann in einem <unk> fährt einen <unk> .',
#  'Ein Junge springt , um einen Tennisball mit seinem Schläger zu treffen .',
#  'Kinder <unk> eine Wand , während zwei andere Personen zusehen .',
#  'Menschen gehen über eine <unk> mit Palmen im Hintergrund .',
#  'Ein kleines Mädchen , das schwarze Reifen trägt , tritt im Freien herum .',
#  'Zwei Männer versuchen , sich von dem Wasser auf einem Gehweg <unk> .',
#  'Zwei Männer tanzen , während eine Menschenmenge zuschaut .',
#  'Ein hübsch gekleidete Frau steht an einem Podium oder <unk> <unk> etwas .',
#  'Eine Frau legt sich auf einem Sofa hinunter und lacht .',
#  'Ein Holzboden wird von einer anderen Person und einer schwarzen Frau <unk> .',
#  'Ein <unk> springt über einen Zaun .',
#  'Drei Hunde spielen miteinander auf dem Feld .',
#  'Zwei kleine Kinder sind im Sand .',
#  'Ein lächelnder kleiner Junge spielt zwischen Büschen im Laub .',
#  'Diese vier Personen stehen im Freien , mit drei Hunden .',
#  'Während der <unk> <unk> aus dem <unk> Square in die Richtung von anderen <unk> .',
#  'Ein Mädchen mit <unk> @-@ T @-@ Shirt ist <unk> .',
#  'Eine <unk> füllt <unk> in die Wüste .',
#  'Ein Mann steht auf einer Straße .',
#  'Ein <unk> fliegt mit Essen in ihrer <unk> weg .',
#  'Zwei Männer fahren durch <unk> <unk> <unk> , <unk> tragen Helme um .',
#  'Zwei Personen stehen auf dem Gipfel eines Berges .',
#  'Ein junges Mädchen , das allein isst , während sie einen Schneeengel macht .',
#  'Drei Männer lächeln für ihre Kamera und zeigen vor ihrem <unk> .',
#  'Eine Person schreibt in einem leeren Klassenzimmer auf eine Tafel .',
#  'Ein Mann in einem schwarzen Hemd sitzt mit einem offenen Laptop vor sich .',
#  'Vier Personen entspannen auf einem grasbewachsenen Hügel mit Blick auf ein <unk> Tal .',
#  'Ein Junge mit einem Skateboard <unk> springt auf einer <unk> <unk> .',
#  'Ein Mann in einem orangefarbenen Hemd spielt Tennis .',
#  'Der Hund mit dem roten Halsband <unk> den Hund mit dem blauen Halsband .',
#  'Der Junge ist im Freien und genießt einen <unk> .',
#  'Ein Arbeiter in einem orangen Anzug beugt sich kopfüber und schwingt ein Stück Maschine .',
#  'Männer mit Cowboyhut stehen bei einem Rodeo herum .',
#  'Zwei Hunde im Schnee , einer von ihnen hat etwas im Maul .',
#  'Ein schneidet , der vom Drink arbeitet , trinkt ein Getränk .',
#  'Ein <unk> Hund rennt einem weißen Spielzeug und hält ein gelbes Spielzeug .',
#  'Ein älterer Spieler in weißer Spielkleidung mit einem Stock .',
#  'Ein Mann in einem weißen Hemd mit einem <unk> <unk> .',
#  'Ein schwarzes Pferd hält seinen Kopf durch einen Zaun und versucht , durchs Gras zu reinigen .',
#  'Ein <unk> <unk> , was er seine Hände <unk> wird , sodass er eine <unk> <unk> .',
#  'Zwei Männer und ein Mädchen lächeln .',
#  'Ein Kind beugt sich über eine Auslage , die aus blauen und gelben <unk> , während ein Erwachsener <unk> .',
#  'Ein schwarz @-@ weißer Hund rennt im Schnee nach einem <unk> Ball .',
#  'Ein junges Mädchen steht neben einer gelben Katze auf einer <unk> .',
#  'Die zwei Kids spielen auf dem Spielplatz .',
#  'Ein Tennisspieler in einem schwarz gestreiften Hemd hält sich die Hand vor den Mund .',
#  'Ein Junge in roter Kleidung spielt im Wasser .',
#  'Ein Kind mit einem roten Mantel und einer Mütze hält einen großen <unk> .',
#  'Zwei Offiziere mit orangefarbenen Jacken stehen vor einem weißen Zelt mit Zuschauern .',
#  'Zwei Personen stehen neben einem Baum auf dem Boden .',
#  'Zwei Männer sitzen neben einem Steingebäude Gebäude und unterhalten sich .',
#  'Ein braunhaariges Kind mit Brille und einem blonden Kind , das einen roten Pullover und gelben Stiefeln trägt .',
#  'Ein schwarz @-@ weißer Hund spielt mit einem weißen Ball .',
#  'Zwei Personen küssen sich auf einem Gehweg vor einer <unk> , während Leute vorbeigehen .',
#  'Eine Frau spielt Volleyball .',
#  'Zwei große Hunde balgen auf einem unbefestigten Feld .',
#  'Ein brauner Hund springt über eine Hürde .',
#  'Ein Mann mit gestreiftem Hemd raucht auf der Straße eine Zigarette .',
#  'Ein kleines Mädchen hält einen kleinen Jungen auf dem Schoß .',
#  'Ein Mann versucht auf einem schönen <unk> Bullen zu reiten .',
#  'Kinder , die sich auf den Sieg eines <unk> beobachten .',
#  'Ein Fahrradfahrer lehnt sich auf einem Mountainbike um eine <unk> .',
#  'Zwei Personen und eine <unk> Kuh .',
#  'Der Junge trifft , wie man auf einem Fahrrad fährt , wie es sich .',
#  'Ein Junge mit einem roten Hemd und schwarzen Shorts kehrt .',
#  'Eine Familie steht vor ein paar <unk> Bäumen .',
#  'Ein Mann spielt neben einem Baum auf einem Instrument .',
#  'Zwei Frauen , die sich an einem Tisch <unk> und lächeln in die Kamera .',
#  'Ein brauner Hund läuft im Gras .',
#  'Ein Baseballspieler in einem schwarzen Oberteil hat einen Spieler in einem weißen Oberteil direkt <unk> .',
#  'Eine Frau hält einen großen <unk> hoch und wird <unk> .',
#  'Die beiden Hunde , einer mit einem Tennisball im Maul , laufen durch hohes Rasen .',
#  'Zwei Erwachsene und zwei Kinder sitzen auf einer Parkbank .',
#  'Eine Frau auf einer Wiese macht einen <unk> .',
#  'Ein Mann verkauft eine Gruppe von Menschen .',
#  'Eine Gruppe von Menschen versammelt sich auf einer Straße , um ein Akkordeon zu hören .',
#  'Ein Mann sitzt auf einer Bank auf dem Gehsteig und <unk> .',
#  'Ein alter Mann in einer U @-@ Bahn @-@ Kleidung liest eine Zeitung .',
#  'Ein älterer Mann mit Brille bereitet Fleisch zu .',
#  'Ein Mann macht einen Trick auf einem Fahrrad , indem er auf dem Lenker steht , ein Kunststück , ein .',
#  'Ein Mann macht am Strand eine Sandskulptur .',
#  'Mehrere Personen in einem Park , die an einem Picknicktisch essen',
#  'Zwei Frauen stehen an einem Baum in einer Art <unk> .',
#  'Ein Cowboy bei einem Rodeo versucht , das <unk> in die <unk> schreit .',
#  'Ein Hund springt durch ein <unk> Hindernis .',
#  'Eine <unk> Frau mit langem schwarzen Haar in einem rosa Oberteil mit einem Namensschild trägt Lippenstift .',
#  'Ein Mann repariert den Fahrrad eines kleinen Mädchens .',
#  'Zwei Mädchen in <unk> tanzen auf der Straße vor ein paar Musiker .',
#  'Der gelbe Hund trägt einen Stock am Wasser .',
#  'Ein Mädchen in einem Pullover <unk> den <unk> an .',
#  'Ein <unk> findet statt .',
#  'Drei Frauen in hellen Kleidern und <unk> halten <unk> in <unk> <unk> auf .',
#  'Ein brauner Hund gräbt im Dreck .',
#  'Ein kleiner Junge mit weiß gestreiftem Hemd und Stirnband hält einen Tennisschläger .',
#  'Zwei Hunde rennen im Wald weg .',
#  'Ein Mädchen spielt in der <unk> <unk> .',
#  'Drei Kleinkinder mit <unk> stehen und hören über einen <unk> .',
#  'Zwei männliche Wanderer untersuchen einen Baumstamm an der Seite eines <unk> .',
#  'Drei Spieler <unk> einen <unk> zu Boden .',
#  'Zwei Jungen überqueren eine Straße , während er einen roten Hund schießt .',
#  'Ein Mann hält einen anderen Arm seinen Rücken in die Höhe .',
#  'Ein weißer Hund auf einem Berg dreht sich nach einem <unk> Himmel , im Hintergrund sind ein Schläfchen im Hintergrund zu sehen .',
#  'Ein Junge fährt mit dem Skateboard auf einer Skateboardrampe .',
#  'Ein langhaariger Typ spielt auf einem Klavier .',
#  'Drei <unk> mit <unk> stehen auf dem Motorrädern auf dem harten <unk> .',
#  'Zwei <unk> in roten Kleidern',
#  'Ein kleiner Junge hängt auf einem <unk> .',
#  'Ein kleines Mädchen in Rosa hält sich an einer Bar fest .',
#  'Ein Mann in grünem Hemd springt mit seinem vollen Motorrad auf dem <unk> .',
#  'Eine Frau spielt in einem Park mit zwei kleinen Jungen .',
#  'Vier Personen spielen am Strand mit einem Fußball .',
#  'Zwei Teenager liegen im Freien , im Hintergrund ist ein kleiner mit einem Fahrradhelm zu sehen .',
#  'Zwei afroamerikanische Hunde laufen durch den Schnee .',
#  'Eine Frau steht mit einem weißen Hund auf einem grünen Feld und zeigt auf einen braunen Hund .',
#  'Ein Tisch voller Bilder in Farben ist auf einem Markt im Freien .',
#  'Zwei Personen sitzen an einem Tisch im Freien an einer Wand und machen Grimassen .',
#  'Zwei Männer mit <unk> @-@ <unk> @-@ <unk> lächeln .',
#  'Ein Kind liegt auf einem beigen Teppich und lacht .',
#  'Ein Mann und eine Frau setzen sich und lächeln mit <unk> <unk> .',
#  'Zwei Frauen schwimmen in einem Planschbecken mit einem <unk> .',
#  'Ein Mann in einem weißen Hemd geht mit einem Getränk in der Hand herum .',
#  'Zwei Menschen stehen als Silhouette gegen ein See <unk> Fluss .',
#  'Mehrere Personen sitzen in formeller Kleidung an einem Tisch .',
#  'Zwei Mädchen , die lächeln , wobei eine blau gekleidet ist , <unk> , <unk> , wobei das andere in <unk> auf einem anderen auf <unk> ein anderes <unk> .',
#  'Vier Personen sitzen auf einem <unk> .',
#  'Eine Gruppe Leute macht auf Motorrädern eine Darbietung Fotos .',
#  'Fahrradfahrer in <unk> fährt durch einen Wald .',
#  'Ein Mann in grünem Hemd geht mit seinem <unk> auf dem Strand .',
#  'Mehrere Männer stehen um ein <unk> @-@ <unk> herum .',
#  'Zwei Männer arbeiten unter der Motorhaube eines weißen <unk> .',
#  'Kinder springen von einer Kante in ein Schwimmbad .',
#  'Ein Mann auf dem Kante einer Mauer , ist dabei , von Erde zu beim .',
#  'Eine Frau in einem gestreiften Outfit , die auf einem Fahrrad steht .',
#  'Ein schwarz gekleidetes Mädchen posiert vor der Kamera .',
#  'Ein Mann in kurzen Hosen am Wasser .',
#  'Vier dunkelhäutige Männer sitzen auf den Stufen einer Kirche .',
#  'Ein Kranich wirbelt viele <unk> .',
#  'Eine Turnerin in rot @-@ weißer Kleidung befindet sich mitten in einem <unk> @-@ <unk> .',
#  'Eine ältere Frau in einem grünen Pullover nimmt Gemüse auf .',
#  'Zwei Männer <unk> mit Werkzeug in einer Werkstatt .',
#  'Ein weiß gekleideter Lehrer und ein kleines Mädchen mit einem gelben Kleid spielen mit einem <unk> .',
#  'Ein kleines Kind schläft in ihrem Bett mit einem offenen Buch auf ihrer Brust .',
#  'Eine Frau , die an einem schönen Tag im Gras isst .',
#  'Ein Mann geht eine Kopfsteinpflasterstraße entlang , neben der Ladefläche mit roten <unk> <unk> sind .',
#  'Eine Frau , die einen Hut trägt , mit Brot .',
#  'Ein einsamer Frau benutzt eine große <unk> und <unk> um sie zu <unk> , während sie in einem <unk> Feld stehen .',
#  'Ein Mann in einem Karateanzug führt vor zwei <unk> auf .',
#  'Ein Mann in förmlicher Kleidung spielt auf dem Gehweg einer Straße in der Stadt .',
#  'Ein älterer Mann sitzt auf einem Stuhl und isst einige Snacks .',
#  'Eine Frau in einem weißen Hemd arbeitet hinter der Theke in einem Café .',
#  'Ein Mann mit Arbeitskleidung auf dem Rücken eines Lastwagens .',
#  'Zwei Kinder schauen auf den Pferden durch einen kleinen Zaun .',
#  'Ein Fenster mit <unk> <unk> .',
#  'Eine Frau in einem hellrosa Mantel macht vor einer Frau in einem rosa <unk> @-@ Rock eine Grimasse .',
#  'Ein Cowboy streckt mit einem <unk> den Arm ab .',
#  'Ein Mann in einem gelben Hemd und ein Mann in einem dunkelblauen Hemd unterhalten sich .',
#  'Drei asiatische Kinder sitzen auf einem Sofa mit <unk> im Hintergrund .',
#  'Ein Mädchen in rotem Hemd springt hoch und schlägt einen Tennisball .',
#  'Ein Mann mit einem grünen Kran posiert in die Kamera .',
#  'Ein Mann mit <unk> @-@ Werbung und eine andere Person lächelt in einem Restaurant .',
#  'Ein Mann schiebt einen <unk> Wagen mit vielen <unk> .',
#  'Ein Mann in einer schwarzen Jacke spielt in der Öffentlichkeit Gitarre .',
#  'Eine Gruppe führt in einem Umzug auf .',
#  'Ein Mann steht auf einem <unk> Felsen mit Blick über ein Gewässer .',
#  'Polizisten <unk> eine Frau , die von einem Bus im Bild <unk> .',
#  'Zwei Polizisten in <unk> schauen über einen Parkplatz .',
#  'Zwei Männer in blauen Hemden betrachten ein Fußballspiel .',
#  'Eine Gruppe Männer in blauen Uniformen steht zusammen .',
#  'Eine junge Frau macht am Strand Yoga .',
#  'Eine große Menschenmenge steht im Park in einem Park , und einige von ihnen spielen auf Instrumenten .',
#  'Ein Mann mit einer <unk> @-@ Kopfbedeckung macht <unk> .',
#  'Ein Mann grillt Fleisch auf einer grillt Fleisch .',
#  'Zwei Männer , die auf einem Markt Obst verkaufen .',
#  'Eine brünette Frau in einem weißen Bikini gießt einem Mann in die Tasse .',
#  'Junge mit Sonnenbrille laufen hinter einem Fahrgeschäft her .',
#  'Eine <unk> hält , vor einem <unk> auf einem <unk> Stein .',
#  'Ein Mann in kariertem Hemd schneidet einem schwarzweißen <unk> .',
#  'Zwei Männer in weißen <unk> sitzen in einem <unk> .',
#  'Ein junges Mädchen in einem roten Kleid trägt einen schwarzen Cowboyhut .',
#  'Ein Mann in rot @-@ weißer <unk> steht auf dem Feld mit einem gelb @-@ blauen Fußball .',
#  'Personen springen über ein <unk> an einem Seil .',
#  'Menschen schauen bei einem Marathon an , wie <unk> <unk> .',
#  'Menschen auf Laptops vor einem großen Fenster .',
#  'Eine <unk> arbeitet , als <unk> <unk> funktioniert .',
#  'Ein Mann mit Handschuhen trägt <unk> <unk> über ein Feld .',
#  'Ein Foto von einem <unk> .',
#  'Eine <unk> Frau hält Ballons bei einer <unk> für eine <unk> Veranstaltung .',
#  'Eine Frau sitzt in einem Zimmer im Zimmer mit einer Katze und zwei <unk> .',
#  'Eine Frau sitzt gegen eine in einem Gebäude gelehnt an einer Ziegelmauer .',
#  'Drei junge Frauen sitzen sich auf roten <unk> gegenüber .',
#  'Eine Frau in einem blauen Hemd geht in einem Dorf .',
#  'Sechs Kinder , sitzen mit <unk> und <unk> auf einer Stufe .',
#  'Ein hellbrauner Hund spielt mit einem Stock am Ende .',
#  'Zwei Hunde beißen einen dritten Hund , der Zunge <unk> hat .',
#  'Ein Kind auf einem Motorrad lächelt .',
#  'Acht Menschen haben sich versammelt , um ein großes Abendessen zu essen .',
#  'Radfahrer werden bei einer Sportveranstaltung im Freien <unk> .',
#  'Ein <unk> fliegt durch New York an einem regnerischen Tag .',
#  'Eine Frau mit blauem Helm und roter Hose fährt auf einem Motorrad .',
#  'Mehrere Männer in <unk> beim Auftritt <unk> .',
#  'Eine junge Frau und ein Mann in <unk> @-@ <unk> @-@ Kostümen <unk> mit einer Gruppe von Menschen im Hintergrund .',
#  'Ein Mann in Uniform geht mit zwei Autos und einem Baum auf einer Straße .',
#  'Junge Frauen klettern auf einen Felsen .',
#  'Ein älterer Mann in einem hellblauen Mantel arbeitet an dem Straßenrand ein Auto .',
#  'Menschen schauen auf einen Tisch mit verschiedenen <unk> auf einem Tisch .',
#  'Ein Mann singt und spielt Gitarre in ein Mikrofon .',
#  'Zwei Männer sitzen in einem Restaurant .',
#  'Zwei Frauen in Shorts laufen einen Strand entlang , der mit dem Wasser entlang ist .',
#  'Bauarbeiter unterhalten sich bei den Gleisen .',
#  'Eine Ansicht auf einem <unk> , einige Mann in einer schwarzen Schürze und mit einer weißen Baseballkappe , die in einem weißen Rand steht .',
#  'Eine Gruppe von Menschen spielt auf einem Objekt .',
#  'Ein kleines Mädchen in blauer Kleidung klettert auf einem <unk> .',
#  'Eine Gruppe Männer sitzt hinter einigen grünen Theke und reden miteinander .',
#  'Ein Mann in einem gelben Outfit steht hinter einem Mikrophon .',
#  'Ein brauner Hund mit einer lilafarbenen Frisbee im Maul .',
#  'Eine Obdachloser , die aussieht , lässt sich an <unk> in der Nähe von anderen <unk> <unk> nass spritzen .',
#  'Eine Frau mit einem Getränk und eine Frau mit einem Handy .',
#  'Ein Kind in einem roten Mantel winkt , wie es eine Hand in die Luft neben einem roten <unk> im Schnee ist .',
#  'Eine Frau sitzt neben ihrer Handtasche und beobachtet Hunde im Park .',
#  'Drei Männer , von denen einer ein Clown <unk> und hält , stehen auf einer Bühne .',
#  'Eine Frau in einem <unk> <unk> in einem Stammeskleidung .',
#  'Die Frau im roten Kleid tanzt mit dem Mann im Anzug .',
#  'Zwei kleine Hunde jagen einen größeren Hund mit einem Tennisball .',
#  'Ein Mann mit <unk> Bart und <unk> sitzt auf einer Parkbank .',
#  'Ein afrikanischer <unk> steht in seinem Garten mit einem Wald im Hintergrund .',
#  'Ein kleines Mädchen versucht eine Ziege zu <unk> .',
#  'Asiaten sitzen in einem Restaurant mit gelben Stühlen .',
#  'Ein kleines Mädchen sitzt im Sitzen auf einem Boden und isst einen <unk> .',
#  'Ein grauhaariger Mann mit schwarzen Handschuhen fährt über das Gras .',
#  'Eine Frau sitzt in einer Reihe roter Stühle und liest ein Buch .',
#  'Ein Kind <unk> während sie auf den Schultern einer Frau fährt .',
#  'Eine Familie geht auf dem Gehweg durch den Schnee , während ein Mann mit seinem <unk> auf der Seite Papier sitzt .',
#  'Eine Katze sitzt auf einem <unk> .',
#  'Ein Mann in einem rosa Hemd und schwarzer Jacke mit Kopfhörern .',
#  'Ein junger Mann ist dabei , einen Football zu werfen .',
#  'Ein Typ und ein Mädchen gehen einen <unk> Gehweg entlang .',
#  'Eine Frau mit rosa Haaren hockt mit <unk> auf dem Gehweg .',
#  'Ein Mann in einem Anzug hält ein Getränk in der Hand , geht auf dem Gehweg neben einem <unk> .',
#  'Ein Mann springt vor einer <unk> im Hintergrund .',
#  'Eine Person in einer roten Jacke und mit schwarzer Hose hält <unk> in der Hand .',
#  'Eine Frau zieht ihren Arm auf eine Person , die im Rollstuhl sitzt .',
#  'Ein Mann mit einer Schürze kocht etwas mit Eiern auf einem <unk> .',
#  'Eine Frau mit einem <unk> <unk> Sonnenbrille und <unk> wartet auf einem Fußgängerüberweg .',
#  'Eine Gruppe von Männern geht eine Straße entlang .',
#  'Eine Straße neben einem chinesischen Ort mit vielen Gebäuden .',
#  'Eine Gruppe schwarz gekleideter Menschen steht auf einem Kai nahe einer langen Struktur .',
#  'Ein Mann trägt ein <unk> Bier zur Schau .',
#  'Ein Mann mittleren Alters setzt sich und spielt Akkordeon .',
#  'Ein Mädchen mit grünen Arm , T @-@ Shirt , Krawatte und <unk> .',
#  'Ein Mädchen in einem rosa Hemd ist am Strand auf das Meer zu .',
#  'Ein Skateboardfahrer in einem schwarzen T @-@ Shirt und Jeans <unk> die Stadt .',
#  'Ein Mann in einer Jacke macht ein Foto von einem großen Gebäude .',
#  'Personen an einem Fußballspiel auf dem <unk> .',
#  'Auf diesem Foto sehen sich eine Familie vier <unk> durch eine belebte Straße .',
#  'Eine Gruppe geht in der Sonne in der Nacht die Straße entlang .',
#  'Eine Straße in der Nähe eines <unk> mit mehreren Menschen mit einem braunen Mantel und Sonnenbrille , die sich an einem Gesicht mit einer Hand vor sein Gesicht .',
#  'Ein paar Pflanzen <unk> in der Nähe des Strands .',
#  'Der Spieler mit dem blauen Helm lässt den Ball und ist bei einem <unk> <unk> .',
#  'Die Frau im goldenen Mantel springt , um die U @-@ Bahn zu fangen .',
#  'Ein paar Leute sitzen auf Bänken unter vielen Bäumen vor einem Gebäude .',
#  'Ein Mann im Anzug sitzt an einer Bushaltestelle .',
#  'Ein Afroamerikaner ist von weißen Eimern umgeben , weißen Eimern , eine dunkelhaarige mit Schnee <unk> gefüllt ist .',
#  'Eine blonde Frau isst etwas und trinkt etwas .',
#  'Ein Mann mit Anzug und Hut spielt auf der Straße Gitarre .',
#  'Eine Frau in einer roten Weste arbeitet an einem Computer .',
#  'Menschen stehen herum und halten <unk> , <unk> in ihren Gesichtern ins Gesicht .',
#  'Ein Mann verwendet mit dem <unk> die Krawatte .',
#  '<unk> <unk> , umgeben von mehreren Personen , während eine glückliche Menschenmenge sitzt und <unk> hört .',
#  'Zwei junge Männer fahren auf einem sehr kleinen <unk> mit <unk> <unk> .',
#  'Eine Frau in einem Kleid geht auf einer Baustelle an einer Baustelle vorbei .',
#  'Ein Kunde im Lebensmittelgeschäft <unk> einem Kunden , der sie kaufen seiner Arbeit nach seinem <unk> und <unk> schiebt .',
#  'Ein Mann mit Sonnenbrille bedient einen Bauarbeiter und eine <unk> auf dem Boden .',
#  'Ein Erwachsener spielt mit seinem Spielzeug , indem es zu einem schwarz @-@ weißen Katze <unk> .',
#  'Ein <unk> trägt eine Gitarre im Wald .',
#  'Ein Mann mit Rucksack geht die Straße entlang .',
#  'Zwei Männer unterhalten sich vor einem <unk> <unk> im Freien .',
#  'Eine schwarz gekleidete Frau hält etwas in ihrem Mund .',
#  'Eine Gruppe sitzt im Freien um einen kleinen , kurzen Tisch .',
#  'Ein Mann fährt mit dem Fahrrad die Rampe hoch .',
#  'Eine Frau in einem schwarzen ärmellosen Hemd und ein Kreuz starrt von einem in die Nähe <unk> .',
#  'Drei Mädchen gehen zusammen den Bürgersteig entlang .',
#  'Eine Frau mit langen Haaren ist bei einer <unk> .',
#  'Ein Mann fährt auf einer Straße Skateboard , während ein anderer Mann vom Bürgersteig aus zusehen .',
#  'Ein Mann in einem schwarzen Ledermantel steht vor einem Schild .',
#  'Ein Mann und eine Frau singen gemeinsam im Freien ein Lied .',
#  'Ein junges blondes Mädchen mit weißem Haar und weißem Hemd liegt im Gras und hält eine Tasche mit <unk> .',
#  'Ein junges Mädchen in grüner Sportkleidung führt eine <unk> .',
#  'Eine Frau geht im Hintergrund an einer Haltestelle des gelben <unk> auf .',
#  'Ein Mann kauert , während er im Hintergrund <unk> und <unk> sich .',
#  'Eine Gruppe Männer steht auf einem Feld mit schwarzen Bällen .',
#  'Ein Tag , der auf einem <unk> in einem örtlichen Platz <unk> wird .',
#  'Ein Mann mit einer Zigarette im Mund , der einen Teller mit Essen bedient .',
#  'Zwei <unk> <unk> sich auf .',
#  'Menschen sitzen auf einer Bank in einem städtischen Platz , an der sich auch eine aus einer <unk> , <unk> und ein <unk> steht .',
#  'Der Arbeiter wirbelt mit einem Eimer um ein Loch .',
#  'Ein Mann mit freiem Oberkörper in schwarzen Shorts steht am Ufer eines großen Gewässers .',
#  'Ein <unk> schaut auf die Stirn nach oben .',
#  'Menschen spielen , eines in einem anderen Hemd , einer in einem blauen Oberteil , der andere mit sich <unk> befindet sich in der Luft .',
#  'Mehrere Personen stehen vor einer Skulptur , die von Wasser umgeben ist .',
#  'Eine Frau sieht zu , wie ein Mann mit <unk> Armen spricht .',
#  'Ein Mann mittleren Alters in weißer Hose und Flipflops schaut hoch .',
#  'Zwei Männer in dunklen orangefarbenen Anzügen und Sandalen stehen nahe einer großen <unk> .',
#  'Zwei Personen haben sich auf ihren Bootes aufgestellt .',
#  'Ein Mann und eine Frau stehen in einer Stadt auf der Straße .',
#  'Ein <unk> aus einer U @-@ Bahn <unk> aus dem Tunnel .',
# ...
#  'Ein Mann in einem türkisen Hemd liest Zeitung .',
#  'Ein Junge in einem Kinderwagen trägt ein grünes T @-@ Shirt und hält ein Buch .',
#  'Zwei Kinder sitzen nebeneinander und essen an der Seite von <unk> .',
#  'Leute fahren auf der Straße Fahrrad , und werden von vielen Hüte auf Fahrrädern .',
#  'Mehrere Personen beim Radfahren .',
#  'Ein Mann sitzt auf einem Bahnsteig mit <unk> wird von einem <unk> gezogen .',
#  'Ein Mann auf einem Fahrrad <unk> durch einen Puck .',
#  'Ein bunt gekleideter junger Mann mit mehreren <unk> @-@ <unk> @-@ <unk> @-@ <unk> sitzt und raucht eine Zigarette .',
#  'Zwei Männer in Anzügen unter einem Schirm und vor einem Regenschirm .',
#  'Ein älterer Mann in einem weißen Oberteil fährt auf einem Fahrrad auf der Straße .',
#  'Ein Mann versucht einen Mann zu klettern , einen Lasso zu klettern .',
#  'Ein Cowboy versucht auf einem Pferd wie er auf einem Lasso einzufangen .',
#  'Zwei Radfahrer mit Helm fahren an ein paar leeren <unk> vorbei .',
#  'Ein Mann bückt sich über eine Couch und zieht dabei etwas aus einer Tasche .',
#  'Ein Mann in einem Motorroller fährt an einem <unk> im Park vorbei .',
#  'Eine Person mit Tätowierungen schaut auf ein Foto auf einer Digitalkamera oder einem <unk> .',
#  'Ein Mann in einem schwarzen Hemd und Jeans steht auf dem Gehweg und schaut in die Kamera .',
#  'Ein Junge und ein Mädchen stehen zusammen auf dem Gehsteig und blicken auf einen Gegenstand .',
#  'Mehrere Personen in blauen Saris und eine in einem grauen <unk> – eine schwarze Bluse trägt .',
#  'Eine Frau und ein Hund sitzen auf einer weißen Bank in der Nähe eines Strands .',
#  'Zwei Frauen gehen in <unk> an einem großen Gebäude .',
#  'Eine Gruppe von Männern und ein Kind in weißen Hemden stehen auf der Straße .',
#  'Eine komplett schwarz gekleidete Frau trägt eine schwarze Tasche auf dem Gehweg .',
#  'Mehrere Männer sitzen an einem Tisch und unterhalten sich .',
#  'Eine Wandmalerei an der Seite eines Gebäudes .',
#  'Ein asiatischer Mann mit Handschuhen arbeitet an einem Essensstand vorbei .',
#  'Eine Frau sitzt an einem Tisch und arbeitet an ihrem Laptop .',
#  'Eine Person sieht sich den Computer an einem Schreibtisch mit einem Telefon und einer Kiste an .',
#  'Ein Mann sitzt auf einem Stuhl und beobachtet die Leute <unk> .',
#  'Zwei Personen mit Hüten stehen auf dem Feld und <unk> sich an einem <unk> .',
#  'Ein paar springt über eine hohe Bar im <unk> .',
#  'Ein Mann in Stiefeln und einem Cowboyhut sitzt bei einem Pferd , und macht einen Sprung , das auf dem steht und sitzen herum .',
#  'Zwei Mädchen sitzen auf der Straße und essen <unk> .',
#  'Drei Kinder in Football @-@ Trikots spielen auf einem Footballfeld , ein anderer Spieler und ein Erwachsener stehen im Hintergrund .',
#  'Ein kleines Kind mit einem schmutzigen Gesicht wird von einer alten Frau gehalten .',
#  'Ein Mann mit Brille schaut in die Kamera , während ein anderer Mann in einem blauen Hemd zusieht .',
#  'Zwei Personen unter einem Baum , auf dem eine grüne Gemüse <unk> ist .',
#  'Ein kleiner Junge mit blauer Kopfbedeckung guckt durch ein Teleskop während ein anderer Junge <unk> .',
#  'Drei Männer kochen in einer kleinen Küche .',
#  'Ein junges Mädchen in einem grauen Schneeanzug fährt auf einem schneebedeckten Berg Ski .',
#  'Eine Gruppe Fußgänger tanzt in einem Tanzen .',
#  'Ein Mann und eine Frau sortieren mit Handschuhen durch <unk> .',
#  'Ein Mädchen sitzt auf einem Holzstuhl .',
#  'Zwei Arbeiter <unk> die Ladung eines Zauns an einer belebten <unk> .',
#  'Ein langhaariger junger Mann fährt an einem schönen Tag auf einem Skateboard .',
#  'Ein Markt im Freien zwei Männer mit einer oder <unk> und <unk> aus dem <unk> .',
#  'Ein Typ in einem weißen Hemd spielt auf einer weißen Gitarre .',
#  'Ein junges Mädchen <unk> ihre Freunde , wie sie eine <unk> Kamera benutzt .',
#  'Ein kleiner Junge springt von einem Steg in einen See .',
#  'Eine Dame mit einer grünen Maske auf dem <unk> und es <unk> sich sehr Freude <unk> .',
#  'Ein Mann mit einer orangefarbenen Jacke und blauem Hut , der einen verschneiten Berg <unk>',
#  'Ein kleines Mädchen mit blondem Haar spielt und planscht in einer Pfütze .',
#  'Ein Kind fährt auf einem Fahrrad einen <unk> entlang .',
#  'Ein Turner wird bei einer <unk> Veranstaltung <unk> .',
#  'Leute gehen mit einem Straßenverkäufer und haben zu Fuß die Straße entlang .',
#  'Ein Mann in einem traditionellen Kleid , der neben seinem <unk> steht , auch nicht aussieht wie <unk> , auch aussieht auch eine <unk> .',
#  'Zwei Kinder spielen auf einem Fahrrad .',
#  'Zwei Männer auf gegnerischen Mannschaften spielen Fußball auf einem Feld .',
#  'Ein Mann springt und posiert für Fotografen , die auf dem Boden liegt .',
#  'Das Mädchen macht ein Getränk aus einem <unk> .',
#  'Der <unk> <unk> <unk> Wasser bei seinem <unk> .',
#  'Ein Mann in einem Laborkittel schaut durch ein Mikroskop .',
#  'Ein blondes Mädchen schläft auf einem braunen Sofa .',
#  'Ein Mann kehrt einen Gehweg vor einem Ziegelgebäude .',
#  'Drei Männer kochen in einer Küche .',
#  'Ein Mann auf einem Gerüst lächelt und posiert für den Fotografen .',
#  'Zwei Mädchen in Shorts halten sich an einem Pool fest .',
#  'Vier asiatische Kinder sitzen auf einer Bank und einem Feld und lächeln in die Kamera .',
#  'Kinder auf Fahrrädern zeigen eine <unk> <unk> .',
#  'Ein kleiner Junge mit einem <unk> und einer Schürze schneidet <unk> in einer Küche .',
#  'Ein Clown .',
#  'Die <unk> hält die <unk> an seinem <unk> fest .',
#  'Ein gelber Bulldozer , der beim <unk> .',
#  'Eine Frau in einem roten Oberteil reitet auf einem <unk> Pferd , der auf dem Ufer <unk> .',
#  'Eine Frau sitzt auf einem sehr großen Felsen und lächelt in die Kamera mit Bäumen im Hintergrund .',
#  'Drei Männer in farbenfrohen Uniformen gehen mit <unk> und <unk> Sonnenbrille hinunter die Straßen .',
#  'Ein Mädchen spielt in einem kleinen Pool .',
#  'Zwei Kinder , ein Junge in einem gelben Hemd und ein Mädchen in blau @-@ weißen Hemden , spielen .',
#  'Ein Mann wirft ein Fischernetz in die <unk> .',
#  'Ein Mann in grauem Hemd , blauen Jeans und eine <unk> mit einer <unk> , steht auf einer <unk> mit einem weißen Lkw im Hintergrund .',
#  'Zwei Bauarbeiter liegen <unk> über Rädern .',
#  'Eine Band auf der Bühne mit <unk> blau gekleideten Team .',
#  'Ein <unk> Herr mit seinem Hemd , der in ein Mikrofon , während er Schlagzeug spielt .',
#  'Ein älterer Mann zieht sein Sachen aus dem Einkaufswagen , damit er auf einem <unk> ist .',
#  'Der Mann mit dem Stock geht spazieren .',
#  'Eine Frau in einem weißen Oberteil arbeitet auf einer <unk> Vorrichtung .',
#  'Ein Mädchen mit einer Maske reitet auf dem Schultern eines Mannes durch einen belebten Rasen .',
#  'Zwei Mädchen , eins ältere und schwarz gekleidet , ein Vater und weiß – führen die Aufmerksamkeit <unk> nach <unk> <unk> <unk> .',
#  'Mehrere Frauen führen einen Tanz vor einem Gebäude auf .',
#  'Ein glatzköpfiger Mann geht auf dem Gehweg und telefoniert dabei .',
#  'Eine Frau spielt mit <unk> <unk> , während ein kleines Kind im blauen T @-@ Shirt läuft .',
#  'Eine Gruppe von Menschen sieht jungen Männern zu , die Keyboard mit langen Eimern spielen , wie er auf den Trommeln spielen .',
#  'Ein Mädchen mit <unk> und <unk> <unk> @-@ <unk> .',
#  'Ein junger schwarzes Auto auf einem <unk> befindet sich und wird von etwas hinter <unk> .',
#  'Zwei schreit singt und spielen auf einer dunklen Bühne .',
#  'Ein Mädchen mit <unk> , weißem T @-@ Shirt , blauem T @-@ Shirt und blauen Shorts steht auf einem mit Steinen <unk> <unk> .',
#  'Zwei Männer spielen vor einem großen Publikum Gitarre .',
#  'Eine Menge tanzt vor einem riesigen Haus mit ihren <unk> .',
#  'Eine Frau und ihr Hund verkaufen im Freien ihre Waren auf den alten Gebäude .',
#  'Eine Frau und zwei Männer , die verkleidet sind , diskutieren .',
#  'Eine Gruppe Männer in roten und schwarzen Jacken wartet auf Motorrädern .',
#  'Ein Mann in einer weißen Uniform mit einer Nummer <unk> auf .',
#  'Ein Mann verkauft bei einer Sportveranstaltung Tomaten .',
#  'Zwei Männer aus dem grünen Team bringen sich bei der anderen Mannschaft an der Hand des gegnerischen Teams den Schlag an .',
#  'Kinder treten , um den Ball zu schießen .',
#  'Eine Person in Blau wirft auf einer Bowlingbahn den Ball nach .',
#  'Mehrere Football @-@ Spieler auf einem Feld in einer Aktion .',
#  'Ein junger Mann sitzt auf einem Skateboard und hält auf dem Bildschirm und posiert .',
#  'Eine blau gekleidete Frau geht einen Marathon hinunter .',
#  'Eine Band macht sich vor Publikum bei einem Publikum auf .',
#  '<unk> <unk> , dass ein <unk> <unk> @-@ Spieler gegen <unk> <unk> <unk> @-@ Spieler versucht ihn zu <unk> .',
#  'Zwei männliche <unk> @-@ Spieler auf dem Weg vor einer <unk> großen Zuschauermenge , werden von ihnen zu .',
#  'Männer spielen auf einem schlammigen Platz Fußball .',
#  'Ein Basketballspieler in einem weißen Trikot hält sich in die Küste und wird von einem Spieler in einem roten Trikot .',
#  'Menschen gehen durch einen anderen <unk> in einer alten Stadt .',
#  'Zwei Autos , ein rot und ein blauer <unk> fahren auf einer Rennstrecke an anderen Zuschauer vorbei und werden von Zuschauern .',
#  'Ein Footballspieler in einem weißen Trikot hält einen Fußball .',
#  'Ein sehr kleiner Junge starrt nach einem kleinen Gegenstand auf ein <unk> Objekt .',
#  'Eine Frau und ein Kind gehen eine Straße entlang .',
#  'Ein Spiel rennt mit vielen Personen .',
#  'Drei Frauen springen im Gras auf Bällen .',
#  'Ein <unk> @-@ Junge in blauen Shorts , einem schwarz @-@ roten Oberteil und weißen Hosen , spielt Tennis .',
#  'Ein Mann und eine Frau in weißen Hemden umarmen einander .',
#  'Ein Mann spricht mit einer <unk> , die eine Art <unk> , während sie selbst <unk> und lächelt .',
#  'Ein kleiner Junge in grünem Hemd legt sich auf einem weißen Bett .',
#  'Ein <unk> Radfahrer hält sich vor , während im Hintergrund die Sonne untergeht .',
#  'Eine Frau in Winterkleidung schlendert in einem verschneiten Gebiet .',
#  'Vier Mädchen und eine Dame , die offenbar <unk> arbeiten .',
#  'Ein Mann in schwarz @-@ weißer Kleidung versucht ein Pferd an .',
#  'Der Herr macht das Bild , bevor die Frau im blauen Oberteil sie <unk> .',
#  'Eine Frau mit roten Haaren steckt <unk> blaues Wasser .',
#  'Zwei kleine Jungen posieren mit einem Stock für ein Foto .',
#  'Vier Kinder trainieren , während zwei Erwachsene zuschauen .',
#  'Ein Mann sitzt auf einem roten Sofa in einem <unk> .',
#  'Eine Gruppe von Personen unterhält sich an Tischen .',
#  'Zwei <unk> liegende Personen , eines in karierten und roten und roten und <unk> , <unk> vor einem <unk> Hintergrund .',
#  'Das rote Auto ist im Hintergrund von zwei Autos zu sehen .',
#  'Ein großer schlafender Mann im Rodeo @-@ <unk> , der von einem Frisbee @-@ Wagen mit seinen <unk> <unk> <unk> gespielt wird , während ein Rodeo @-@ Kreis <unk> .',
#  'Ein Mann mit nacktem Oberkörper geht auf einen gelben Kajak zu .',
#  'Ein Junge auf einem <unk> @-@ <unk> und macht eine <unk> .',
#  'Zwei <unk> spielen im Sand Football .',
#  'Ein blau gekleidetes Kind und ein weiß gekleidetes Kind stehen auf einer kleinen Beton neben einem Strom .',
#  'Eine Frau trägt ein Muster @-@ Muster auf einem <unk> .',
#  'Leute gehen in einem <unk> Land eine <unk> Straße entlang .',
#  'Ein <unk> <unk> Pitcher wirft den Ball und wirft einen Ball .',
#  'Zwei Männer , einer schwarz @-@ weiß , einer rot gekleidet , spielen Beachvolleyball .',
#  'Ein Mann steht in einem Boot und hält <unk> in der Hand .',
#  'Ein Surfer ist gerade von seinem Surfbrett auf dem Meer und versucht auf einer Welle zu springen .',
#  'Ein <unk> bereitet eine <unk> im Laborkittel vor .',
#  'Fußballspieler springen in die Luft , um der Ball mit ihrem Kopf zu schlagen .',
#  'Zwei Jungen spielen Football .',
#  'Eine ältere Person überquert mit einem Regenschirm in den Händen eine Straße .',
#  'Eine Gruppe Läufer rennt auf zwei <unk> <unk> .',
#  'Ein Skateboarder fährt auf einer Betonmauer hoch , die fast <unk> hat , von ihm ein Kunststück .',
#  'Menschen spielen im Pool ein Spiel .',
#  'Ein Typ , der ebenfalls eine <unk> Mann <unk> .',
#  'Ein Mann , der in einem kleinen Jungen einen <unk> , in einem <unk> .',
#  'Ein junger Mann in blauem Hemd schleift in einem städtischen Gebiet ein <unk> .',
#  'Ein asiatischer Mann sitzt auf der Veranda mit vielen <unk> .',
#  'Ein <unk> trägt in kompletter <unk> Kleidung und <unk> seinen Hut und mit einem <unk> Leuten , die auf dem <unk> <unk> sitzen , blickt .',
#  'Zwei Autos fahren auf einer Rennstrecke .',
#  'Ein Mann in einem schwarz @-@ weißen Trikot mit gelber <unk> hält gelbe <unk> und macht sich bereit .',
#  'Zwei Personen liegen und küssen sich auf einer Wiese .',
#  'Ein sehr kleines Kind in einer Jeans @-@ Baseballkappe isst einen grünen Schal .',
#  'Der Football @-@ Spieler rennt , um den Ball zu bekommen .',
#  'Ein Mann in einer schwarzen Jacke und mit schwarz @-@ weiß gestreiften Hosen spielt auf einer Bühne mit einer kleineren Gitarre und spielt auf einer Bühne im Hintergrund mit einer anderen Gitarre .',
#  'Ein Mann springt von einem Bullen über eine <unk> .',
#  'Eine Frau in einem blauen Oberteil und weißer Hose spielt Tennis .',
#  'Ein Mann spielt bei einem Konzert ein <unk> .',
#  'Ein Mann trägt einen großen <unk> auf seiner Schulter durch einen <unk> .',
#  'Eine Frau wirft mit einem Frisbee @-@ Frisbee @-@ Scheibe eine Frisbee zu ihrem braunen Hund .',
#  'Eine <unk> und einer Frau , die <unk> ein <unk> oder eine <unk> <unk> .',
#  'Zwei Mädchen , die in einem Brunnen gehen , während sie Personen gehen .',
#  'Ein <unk> , lächelnde Kind mit freiem Oberkörper posiert mit <unk> .',
#  'Zwei Männer , einer weiß gekleidet , der andere blau .',
#  'Eine Frau in einem roten Bikini springt am Strand , um beim Strand zu treffen .',
#  'Eine orangefarbene <unk> trägt ein <unk> Mädchen auf die Nase .',
#  'Eine Frau mit gelber Schürze macht den Deckel von einem großen Topf .',
#  'Zwei Kinder überqueren einen kleinen <unk> mit einer <unk> .',
#  'Zwei afroamerikanische Frauen fahren auf einem Moped eine Straße entlang , die meisten mit einem großen <unk> abgesperrten Bereich <unk> scheint .',
#  'Zwei Jungen vor einer <unk> Maschine .',
#  'BMX @-@ Fahrer in schwarzer Kleidung fährt in einem Mountainbike einen Feldweg entlang .',
#  'Eine Dame mit Tätowierungen macht ein Foto von einem Bild mit ihren <unk> .',
#  'Eine Frau in einem <unk> schwarzen Outfit und mit weißen Helm fährt auf einem Fahrrad mit <unk> im Hintergrund .',
#  'Ein <unk> eine <unk> Menschenmenge , während er sich in der Nähe von Zuschauern und <unk> .',
#  'Vier Football @-@ Spieler in schwarz versuchen den gegnerischen Teams zu gegnerischen , der Mitglieder schwarz',
#  'Ein Läufer wird von zwei <unk> <unk> .',
#  'Der Basketballspieler im weißen Trikot verfolgt den Spieler mit der Nummer Mannschaft in der schwarzen Spielkleidung mit der Nummer Mannschaft im <unk> @-@ <unk> .',
#  'Ein Mann spricht am Handy .',
#  '<unk> Baseballspieler spielen bei der <unk> <unk> @-@ <unk> @-@ Spiel .',
#  'Geländemotorradfahrer fahren im Herbst auf <unk> um eine <unk> Kurve .',
#  'Drei Basketballspieler spielen nach dem Ball , einer im roten Trikot versucht , den Ball zu <unk> .',
#  'Ein Junge streckt sein Bein , während er in die Luft springt .',
#  'Zwei Kinder mit gestreiften Pullovern und schwarzen Hosen <unk> im Freien bei einem <unk> .',
#  'Ein Mann mit Sonnenbrille fährt Motorroller .',
#  'Ein kleiner Junge mit <unk> hält einen Schläger hinter sich hinter seinem Kopf , mit einem Baseball vor sich .',
#  'Sechs Männer sitzen mit <unk> in einem Feld .',
#  'Ein brauner Hund holt einen <unk> aus einer <unk> .',
#  'Ein Mann in Gelb hält ein braunes Pferd mit dem <unk> eines braunen Hauses .',
#  'Ein Mann mit weißem Hemd und Schürze schneidet einen Hund hoch .',
#  'Eine <unk> Frau verwendet eine <unk> , um zu kochen .',
#  'Marathonläufer rennen auf einer Straße mit anderen Leuten .',
#  'Eine Asiatin trägt einen Turban , während sie auf dem Fahrrad fährt .',
#  'Ein paar Kinder spielen im Freien mit zwei Bäumen .',
#  'Ein älterer Mann spielt ein Videospiel <unk> @-@ <unk> .',
#  'Ein Mädchen am Strand mit einem Berg in der Ferne .']

# %%
with open('result/pred(epoch_31).txt', 'w') as f:
  for line in pred:
    f.write(line + '\n') # txt 파일로 번역 문장 작성
f.close()

# %%
with open('multi30k/test.de.atok', 'r') as f:
  lines = f.readlines()
  for line in lines:
    print(line)
# Out:
# Ein Mann mit einem orangefarbenen Hut , der etwas anstarrt .
#
# Ein Boston Terrier läuft über saftig @-@ grünes Gras vor einem weißen Zaun .
#
# Ein Mädchen in einem Karateanzug bricht ein Brett mit einem Tritt .
#
# Fünf Leute in Winterjacken und mit Helmen stehen im Schnee mit Schneemobilen im Hintergrund .
#
# Leute Reparieren das Dach eines Hauses .
#
# Ein hell gekleideter Mann fotografiert eine Gruppe von Männern in dunklen Anzügen und mit Hüten , die um eine Frau in einem trägerlosen Kleid herum stehen .
#
# Eine Gruppe von Menschen steht vor einem Iglu .
#
# Ein Junge in einem roten Trikot versucht , die Home Base zu erreichen , während der Catcher im blauen Trikot versucht , ihn zu fangen .
#
# Ein Typ arbeitet an einem Gebäude .
#
# Ein Mann in einer Weste sitzt auf einem Stuhl und hält Magazine .
#
# Eine Mutter und ihr kleiner Sohn genießen einen schönen Tag im Freien .
#
# Männer , die Volleyball spielen , wobei ein Mann den Ball nicht trifft , während seine Hände immer noch in der Luft sind .
#
# Eine Frau , die in einer Küche eine Schale mit Essen hält .
#
# Ein sitzender Mann , der an einem Tisch in seinem Haus mit einem Werkzeug arbeitet .
#
# Drei Leute sitzen in einer Höhle .
#
# Ein Mädchen in einem Jeanskleid läuft über einen erhöhten Schwebebalken .
#
# Eine Blondine hält mit einem Mann im Sand Händchen .
#
# Eine Frau in einem Grauen Pulli und mit einer schwarzen Baseballmütze steht in einem Geschäft in der Schlange .
#
# Die Person im gestreiften Shirt klettert auf einen Berg .
#
# Zwei Männer tun so als seien sie Statuen , während Frauen ihnen zusehen .
#
# Leute , die vor einem Gebäude stehen .
#
# Eine Teenagerin spielt bei einem Spiel Trompete auf dem Feld .
#
# Eine Frau macht einen Salto auf einem Trampolin am Strand .
#
# Ein Mann steht bei einigen Spielautomaten in einer Bar .
#
# Eine Frau verwendet eine Bohrmaschine während ein Mann sie fotografiert .
#
# Eine Frau in einem pinken Pulli und einer Schürze putzt einen Tisch mit einem Schwamm .
#
# Ein Mann schneidet Äste von Bäumen .
#
# Eine Gruppe Asiatischer Jungen wartet am Grill darauf , dass Fleisch gar wird .
#
# Frauen , die traditionelle Kleidung tragen , spielen das Leben Einheimischer nach .
#
# Ein Mann drückt den Kopf eines anderen Mannes nach unten und will ihm ins Gesicht schlagen .
#
# Sechs Leute fahren Mountainbikes durch eine Dschungellandschaft .
#
# 2 blonde Mädchen sitzen auf einem Absatz auf einem belebten Platz .
#
# Ein Kind planscht im Wasser .
#
# Drei Leute sitzen an einem Picknicktisch vor einem Gebäude , das wie der Union Jack bemalt ist .
#
# 3 Jungen stehen in ihren Badehosen auf einem Pier .
#
# Ein Angestellter reicht einer Frau auf einem Markt eine Tüte , während sie auf Eis gelegten Fisch begutachtet .
#
# Eine schöne Frau spielt auf einer Harfe .
#
# Vor einem Gebäude sieht ein uniformierter Sicherheitsbeamter hinter einem Zaun in die Kamera .
#
# Die junge Dame sieht auf die Pizza .
#
# Ein Mann mit freiem Oberkörper und Shorts steht auf ein paar Steinen und angelt .
#
# Ein Mädchen in einer Rettungsweste treibt im Wasser .
#
# Ein Mann in Uniform und ein Mann in einem blauen Hemd stehen vor einem Wagen .
#
# Leute sitzen in einem Zug .
#
# Ein Junge schaukelt mit den Füßen in der Luft in einem Wald .
#
# Ein Mann in einem roten Hemd betritt ein Etablissement .
#
# Zwei Männer in Badehosen springen auf einem mäßig belebten Strand in die Luft .
#
# Ein kleines Kind kocht mit einer anderen Person .
#
# Eine Vaterfigur und zwei Kinder machen vor ihrem Zuhause Gartenarbeit wie den Rasen mit einer Gartenhacke zu bearbeiten und einen Baum zu pflanzen .
#
# Ein Mann bereitet am Herd Essen zu .
#
# Ein Mann in Jeans spielt an einem Strand mit einem roten Ball .
#
# Leute gehen auf einem Gehsteig neben einer Reihe von Geschäften .
#
# Ein Wakeboarder macht einen Salto während er bei hoher Geschwindigkeit an einem Seil gezogen wird .
#
# Eine große Menschenmenge füllt eine Straße .
#
# Ein Mann an einem Halteseil geht ins Wasser .
#
# Eine Frau in Jeans läuft vor einem Bus vorbei , auf dem eine Werbung eine Frau zeigt , die über den Rand ihrer Sonnenbrille blickt .
#
# Ein Mann in einem pinken Hemd sitzt auf dem Gras und ein Ball ist in der Luft .
#
# Ein am Strand geparktes Auto .
#
# Zwei Männer in Schwarz in einer Stadt
#
# Der Mann in der gelben Hose hebt seine Arme .
#
# Zwei Männer mit Hüten und Spazierstöcken schlendern neben einem Gewässer bei Sonnenuntergang .
#
# Ein Cheerleaderteam macht eine Übung auf Stühlen .
#
# Ein Junge spielt mit einem Erwachsenen außerhalb des Bildes Dame während ein Mädchen zusieht .
#
# Eine Gruppe Menschen , die sich in einem öffentlichen Park amüsieren wollen .
#
# Ein Mann sitzt auf einer Bank während er seinen Hund hält und aufs Wasser blickt .
#
# Ein Junge und sein jüngerer Bruder spielen gemeinsam auf einem Spielplatz .
#
# Ein blau gekleidete Frau sieht in eine schwarze Ledertasche während sie an einem sonnigen Nachmittag auf einer Bank sitzt und Menschen und Autos hinter ihr vorbeiziehen .
#
# Der braune Hund steht auf dem Sandstrand .
#
# Eine Frau Sitzt mit einem Korb voller Stoff , umgeben von Stoff .
#
# Ein Mann grillt im Freien in seinem Hof .
#
# Eine Frau singt in einem Klub mit einem Gitarristen hinter ihr .
#
# Gitarristin spielt in einem Nachtklub auf einer roten Gitarre .
#
# Ein Kind sitzt auf einem Gartenstuhl und sieht zur Kamera auf
#
# Zwei Frauen und drei Männer blicken auf den Ozean .
#
# Eine Musikantin mit einer Violine spielt auf der Straße während eine Frau mit einer blauen Gitarre zusieht .
#
# Ein junges Mädchen schwimmt in einem Pool
#
# Mehrere Kinder sind im Freien und bereiten sich auf Tauziehen vor .
#
# Drei Teenager in einer U @-@ Bahn albern herum .
#
# Ein brauner Hund läuft durchs Gras und seine Zunge hängt heraus .
#
# Leute sitzen vor einem Gebäude im Gras und machen Pause .
#
# Mann ohne Hemd starrt vor einem Café in die Ferne während drei Frauen an einer Menschenmenge vorbeigehen .
#
# Zwei Jungen packen Obst auf das Fahrrad .
#
# Ein Mann in einem schwarzen T @-@ Shirt spielt Trommel auf einem umgedrehten gelben Kübel .
#
# Eine junge Künstlerin malt ein Bild einer Frau auf eine Wand .
#
# Zwei Spielerinnen der US @-@ Nationalmannschaft klatschen im Sprung ab , umgeben von zwei weiteren Spielerinnen .
#
# Ein Mann rührt in einem Topf in seiner Küche .
#
# Ein Junge beim Wakeboarden auf dem See .
#
# Ein Mann arbeitet an einem Hotdog @-@ Stand .
#
# Eine große Gruppe von Menschen unterschiedlichen Alters und Geschlechts sitzt gemeinsam im Freien .
#
# Eine blonde Frau schenkt an einer Bar Getränke ein .
#
# Ein kleines Kind in einem blau @-@ weißen T @-@ Shirt hält glücklich einen gelben Plastik @-@ Alligator .
#
# Eine schwarz gekleidete Frau mit rosa Haaren spricht mit einem Mann .
#
# Der Mann im japanischen Kochgewand bereitet ein Essen für zwei Personen zu .
#
# Ein Mädchen springt von Fels zu Fels über den Bach .
#
# Ein Arbeiter mit Werkzeugkiste kniet neben zwei Frauen .
#
# Ein älterer Mann breitet seine Arme aus und blickt verblüfft .
#
# Ein Kind in einem weißen Karateanzug übt eine Bewegung .
#
# Drei Männer in gleichfarbigen Westen halten sich im Freien auf .
#
# Eine Frau macht ein Bild von einem Baby mit rosa Mütze , das von einem Mann getragen wird .
#
# Eine Gruppe überwiegend asiatischer Kinder sitzt in Arbeitsnischen verteilt auf blauen Stühlen .
#
# Ein kleiner Junge im Fußballdress hält die Hände vors Gesicht und weint .
#
# Eine glückliche Frau bereitet in einem Coffee @-@ Shop eine Erfrischung zu .
#
# Ein Bauarbeiter bewegt schweres Gerät auf einer Baustelle .
#
# Eine Frau läuft beim Softball nach einem erfolgreichen Schlag los während die Fängerin sich erhebt .
#
# Ein Mann in Arbeitskleidung reicht einer anderen Person ein Werkzeug .
#
# Eine Gruppe klettert bei kaltem Wetter .
#
# Ein Bergsteiger mit einem blauen Helm beginnt mit dem Abstieg .
#
# Ein Mann macht einen Handstand auf einer runden Skulptur .
#
# Ein Kind sitzt an einem Restauranttisch und hält eine Papiermaske vors Gesicht .
#
# Ein brauner Hund watet in einen See , um einen Stock zu holen .
#
# Eine Mutter bringt ihren zwei kleinen Söhnen an einer felsigen Küste mit sehr blauem Wasser das Angeln bei .
#
# Ein kleines Kind läuft neben roten Stühlen .
#
# Ein Mädchen sitzt mit einem kleineren Jungen auf einem dekorierten Fahrrad während ein weiteres Mädchen ein Foto macht .
#
# Ein Schwarzer Hund holt einen Ball im Wasser .
#
# Ein Mann in weißen Hosen und einem blauen Hemd tritt gegen einen gelben Boxsack .
#
# Zwei indische Männer nehmen an einer Zeremonie teil .
#
# Ein Junge mit verschrammter Nase und bekritzelten Händen steht in einer Videothek .
#
# Zwei Silhouetten paddeln in einem Kanu auf dem Ozean bei Sonnenuntergang .
#
# Menschen stehen in einer vollen U @-@ Bahn , der Bahnsteig draußen ist durch das Fenster zu sehen .
#
# Mann erklettert Mauer mit Feuer in der Hand
#
# Zwei braune Hunde rennen durch den Schnee .
#
# Bühnenfoto einer kleinen Band , die für ein Theaterpublikum spielt .
#
# Ein Baby im Weihnachtskostüm blickt in die Kamera .
#
# Ein Mann Sitzt neben einem Computermonitor .
#
# Diese Frau hat gerade einen lustigen Witz gehört und lacht .
#
# Personen in einem Gebäude , eine von ihnen macht ein Foto .
#
# Vier weiße Hunde mit Maulkörben springen über eine rote Wand .
#
# Die Frau im blauen Shirt hält ein Baby .
#
# Zwei Personen sitzen auf gestreiften Liegestühlen und angeln in einem Gewässer .
#
# Eine alte Frau sitzt an einem Webstuhl und stellt Stoff her .
#
# Ein Junge im Vordergrund blickt über andere Personen auf einem Platz .
#
# Ein Mann in einer blauen Jacke hält einen Jungen an der Schulter .
#
# Drei braune Hunde springen an der blau gekleideten Frau hoch .
#
# Ein Junge hängt aus dem Fenster eines vorbeifahrenden Taxis .
#
# Ein Mann in einem grauen Shirt springt über die Spitze einer Sanddüne in der Wüste .
#
# Ein Kind in einem gelben Shirt springt rauf und runter .
#
# Ein Arbeiter in einer gelben Jacke wird auf ein Gebäude gehoben , um zu arbeiten .
#
# Ein Mann in Brasilien unterhält sich mit jungen Erwachsenen .
#
# Ein paar Bier @-@ Zapfhähne in einer Bar mit Weihnachtsdekoration an der Decke .
#
# Ein Mann seilt sich an einer Klippe über dem Ozean ab .
#
# Ein Mann in schwarz geht im Schnee zu seinem Fahrzeug .
#
# Ein Foxterrier springt nach einem Ball .
#
# Eine Polizistin mit Mütze und blauer Uniform trägt eine Sonnenbrille und lächelt vor einem Geschäft .
#
# Eine Familie spaziert durch einen Park .
#
# Ein Mann mit einem grünen Schutzhelm und Sicherheitsweste blickt ernst .
#
# Ein Kind mit pinken Fäden auf dem Kopf tanzt umgeben von Konfetti und Ballons .
#
# Ein Hund mit Stupsnase schnuppert nach etwas an einem Flussufer .
#
# Ein Mann bereitet seinen Stand für das Tagesgeschäft vor .
#
# Ein Mann in einem roten Hemd schickt sich an , einen Taco zu essen .
#
# Eine junge Dame in weiß hält einen Tennisschläger .
#
# Ein Junge in einem roten Shirt gräbt mit einer gelben Schaufel im Sand .
#
# Eine Person in einer rosa Jacke sitzt untätig auf einer hölzernen Bank .
#
# Ein Mann in einem weißen Hemd blickt durch ein Fenster einer Metallkonstruktion .
#
# Eine Frau hält eine kleine weiße Statue .
#
# Sechs Kinder ohne Hemd spielen in natürlichem Gewässer und planschen .
#
# Zwei Personen fahren auf Fahrrädern durch eine Gebirgslandschaft .
#
# Ein Mädchen beim Seilhüpfen auf dem Gehweg nahe einer Garage .
#
# Ein Mann trägt ein orangefarbenes Shirt und einen Helm .
#
# Ein kleiner Junge spielt mit Plastikklötzen , Autos und Tieren während eine Erwachsene ihn aufmerksam beobachtet .
#
# Ein kleines Mädchen , das ein Weihnachtsgeschenk auspackt .
#
# Die blau gekleidete Frau bedient eine Kamera vor zwei anderen Frauen .
#
# Ein kleines Mädchen versucht auf einem gemütlichen Sofa ein Nickerchen zu machen .
#
# Ein braun @-@ schwarzer Hund läuft auf einem Pfad im Wald .
#
# Zwei Hunde spielen an einem Baum .
#
# Ein Marineoffizier in einem schwarzen Mantel und Hose steigt Treppen während die Kamera auf den Hund fokussiert .
#
# Zwei grün gekleidete Männer bereiten in einem Restaurant Essen zu .
#
# Ein Mann in schwarzem Leder und einem Cowboyhut schlendert auf einem Renaissancefestival .
#
# Ein Hund läuft mit einem gelben Spielzeug im Freien .
#
# Ein Hund , der einen Mantel trägt , läuft im Schnee .
#
# Eine Familie spielt am Strand mit ihrem Hund .
#
# Eine Frau und ein Kind umarmen sich während das Kind kostet , was sie gerade gemeinsam zubereiten .
#
# Zwei Männer und eine Dame stehen im Freien .
#
# Eine Gruppe von Männern verwendet Baumstämme , um ein Boot aus dem Wasser zu schieben .
#
# Ein Mann trinkt aus einem Weinglas während er eine Zeitung liest .
#
# Ein ganz in schwarz gekleideter Mann spielt Piano .
#
# Ein Junge in einem blauen Trikot und gelben Shorts spielt Fußball .
#
# Ein Mann steht auf einem Stein und breitet seine Arme aus wie ein Vogel .
#
# Ein Hund trinkt draußen Wasser auf dem Gras .
#
# Zwei Frauen in Tank @-@ Tops blicken in die Kamera .
#
# Ein Mann sitzt im Friseurstuhl und bereitet sich auf eine Rasur vor .
#
# Ein kleines Kind in grünen Stiefeln spielt in einer Schlammpfütze .
#
# Ein Mann schneidet Holz mit einer Kettensäge .
#
# Ein Mann sitzt an einem Picknicktisch mit einem Tablett und halb ausgetrunkenem Bier vor sich .
#
# Der Junge im schwarzen T @-@ Shirt und blauen Jeans hält einen roten Baseballschläger .
#
# Ein dunkelhaariger Mann mit Bart , Brille und Hawaiihemd sitzt auf dem Gras .
#
# Hunde Laufen auf einer Hunderennbahn .
#
# Ein Lichttechniker mit Tribal @-@ Tattoos richtet einen Scheinwerfer über einen Balkon .
#
# Zwei Deutsche Schäferhunde knurren einander an .
#
# Das ist eine Gruppe von Leuten , die auf einem Event herumstehen .
#
# Ein braun @-@ weißer Hund holt ein Spielzeug .
#
# Ein weißhaariger Mann spielt Akkordeon zwischen ein paar Gebäuden .
#
# Eine Frau mit braunen Haaren sitzt auf einer Bank vor einem Café .
#
# Ein Mann spielt neben einem Fahrrad Panflöte .
#
# Zwei Kinder balancieren auf einem Stamm und halten ein Seil .
#
# Ein Mann auf einem Motorrad zeigt einen Trick auf einer Rennstrecke .
#
# Eine junge Frau mit einem purpurnen Tuch über dem Gesicht entspannt auf einem hölzernen Deck .
#
# Die Frau im braunen Shirt sitzt auf einer hellroten Bank .
#
# Ein Hund läuft auf einem Baumstamm über einen kleinen Fluss .
#
# Ein junger Mann in einem weißen T @-@ Shirt und grün @-@ schwarzen Shorts steht auf einem Pfeiler .
#
# Alle Personen in der Gruppe stehen unter Regenschirmen .
#
# Ein Mann macht Werbung mit einem riesigen Schild , das auf sein Fahrrad gebunden ist .
#
# Ein Mann wirft einen Ast in einen Kanal während zwei Hunde zusehen .
#
# Gruppe älterer Menschen , die in einem Zelt am Wasser Instrumente spielen .
#
# Eine Ansicht einer belebten Straße in der Stadt .
#
# Eine junge blonde Frau hält ein weißes Seil an einem sonnigen Tag .
#
# Zwei Personen in blauen Hemden stehen mit einem Megafon im Freien .
#
# Ein schwarzer Hund springt in einen Pool .
#
# Ein Cowboy reitet ein Wildpferd in einem Wettbewerb .
#
# Eine Gruppe von Bahnarbeitern macht Wartungsarbeiten an Bahngleisen .
#
# Ein Arbeiter in einer orangefarbenen Weste arbeitet mit einer Schaufel .
#
# Zwei Bauarbeiter diskutieren auf einer Baustelle .
#
# Drei Männer gehen bergauf .
#
# Eine asiatische Frau in einem Hochzeitskleid mit Blumenmuster posiert mit ihren Brautjungfern auf einer Brücke .
#
# Ein junger Mann stimmt seine Gitarre in der Küche .
#
# Drei Jungen spielen mit Schwämmen und Wassereimern .
#
# Drei Arbeiter machen Ausbesserungen auf dem Gehsteig .
#
# Leute entspannen in einem Wald neben Kanus .
#
# Ein Chor versammelt sich in einer Kirche .
#
# Eine Gruppe Teenager springt bei Nacht in die Luft und macht lustige Posen für die Kamera .
#
# Zwei Männer fahren in Kajaks , eines orange und das andere blau , einen Fluss hinab .
#
# Zwei Arbeiter streichen Zement auf einen Ziegelbau .
#
# Eine Dame in einem rötlichen Sweater und Jeans sitzt mit den Händen auf ihrem linken Knie .
#
# Zwei Schauspieler inszenieren einen Kampf vor einen gebannten Publikum .
#
# Ein Soldat entspannt und wartet auf einem Flughafen .
#
# Ein Mann in einem gelben Mantel achtet auf ein Feuer , ein Junge im Anorak sieht zu .
#
# Ein Mann und ein Junge auf einem felsigen Strand .
#
# Eine Frau auf einem Boot namens " El Corazon " lässt schwarze Gewichte ins Wasser fallen .
#
# Ein Junge sitzt auf einem Fernrohr und schaut hindurch .
#
# Ein barfüßiges junges Mädchen in einem rosa Kleid springt im Freien .
#
# Viele Menschen sitzen um ein Zelt im Freien .
#
# Ein Jugendlicher in einem schwarzen T @-@ Shirt mit dem Aufdruck " Asian Pacific 2007 " sitzt und spielt eine Trommel .
#
# Ein Mann verkauft Waren am Rand der Straße , die zu einem Großen Berg im Canyon führt .
#
# Das Mädchen in Gelb lacht das Mädchen in Orange aus während das Mädchen in Blau zusieht .
#
# Ein Hund springt im Freien über ein Hindernis .
#
# Hund mit schwarzem Halsband wälzt sich in Staub und trockenen Blättern .
#
# Zwei braune Hunde spielen grob miteinander .
#
# Ein Mann mit Schnurrbart und Bart hält eine Pfanne , aus der Flammen hochsteigen .
#
# Ein Mann mit Kleidung aus dem Unabhängigkeitskrieg schlägt eine Glocke .
#
# Ein Mann in einem schwarzen Shirt angelt an einem felsigen Ufer .
#
# Zwei Hunde beschnuppern sich gegenseitig Nase an Nase .
#
# Zwei Männer unterhalten sich auf dem Gehsteig während ein Auto vorbeifährt .
#
# Ein Chinese sitzt und wartet auf Kundschaft .
#
# Geparkte Autos mit einem Schulbus dahinter .
#
# Zwei Frauen in ähnlichen T @-@ Shirts gehen nach links .
#
# Ein kleines Kind in einer orangefarbenen Rettungsweste hält ein Paddel und paddelt in einem blauen Kajak auf einem Gewässer .
#
# Menschen gehen auf einem Pfad in einem Park voller Bäume .
#
# Drei Jugendliche reden in einer Menschenmenge , die Frau blickt verärgert .
#
# Eine Frau und ein Kind vor der Tür ihres idyllischen Hauses .
#
# Ein schwarzer Mann und seine zwei weißen Freunde stecken die Köpfe zusammen .
#
# Eine junge Frau in Tarnhose sitzt auf einem Hummer @-@ Truppentransporter .
#
# Ein hellbrauner Hund läuft bergauf .
#
# Ein Junge posiert mit einem großen grünen Insekt auf der Nase .
#
# Ein glatzköpfiger Mann demonstriert , wie hoch sein braun @-@ schwarzer Hund springen kann .
#
# Eine Menschenmenge auf einer geschäftigen Straße bei Tag .
#
# Ein Windhund mit Maulkorb in gelb und schwarz läuft auf der Strecke .
#
# Ein Mann in Sandalen sitzt auf dem Gehsteig neben ein paar Taschen .
#
# Ein Mann und eine Frau sitzen an einem Zaun und unterhalten sich .
#
# Ein Kind sieht sich Kaffeemaschinen in einem Geschäft an .
#
# Ein Mann , der aus einer gelben Tasse Trinkt , umgeben von Menschen auf einer geschäftigen Veranstaltung .
#
# Ein Junge lehnt sich an ein Auto mit Blumen auf der Motorhaube .
#
# Eine Frau in einem Kleid mit Blumenmuster spricht mit Kindern vor einem Kleinbus .
#
# Ein Mann an seinem Hochzeitstag .
#
# Eine junge Frau in einem schwarzen T @-@ Shirt und Jeans beim Kehren .
#
# Eine Frau mit einer Mütze klettert auf einer Klippe nahe eines großen Gewässers .
#
# Ein großer schwarzer Pudel läuft auf dem Gras mit einem Spielzeug im Maul .
#
# Ein Junge in Shorts macht einen Skateboard @-@ Trick .
#
# Ein kleiner Junge in roten Hosen steht auf der Straße .
#
# Eine Frau tippt auf ihrem Handy , umgeben von Regenschirmen .
#
# Acht Männer spielen auf der Bühne , während ein Gitarrist im Scheinwerferlicht spielt .
#
# Ein Mann in einem orangefarbenen Overall und passendem Schutzhelm hilft mit einem blauen Schlauch
#
# Ein Mann und zwei Mädchen mit Angelruten vor einem Gewässer halten einen Fisch hoch .
#
# Ein Mann in einem roten Shirt beobachtet einen Hund beim Hindernislauf .
#
# Ein Junge in einer rot @-@ weißen Badehose springt rückwärts in einen schönen Pool .
#
# Eine Asiatin steckt ihre Haare zurück .
#
# Ein ältere Frau und ein kleines Kind in einem pinkfarbenen Shirt spielen mit bunten Klötzen .
#
# Ein kleiner schwarzer Hund springt über Gatter
#
# Ein Mann mit braunen Haaren in einem grünen Hemd spielt im Freien Trompete .
#
# Ein Mann telefoniert mit hochgelegten Füßen .
#
# Ein Gruppe Kinder sitzt auf einer Blauen Matte und isst aus Schalen .
#
# Ein schwarzer Junge sitzt im Sand .
#
# Ein kleiner Hund sieht zu wie zwei größere Hunde auf einem Feld stürmisch spielen .
#
# Menschen , die vor einem großen Gebäude im Kreis sitzen .
#
# Ein Hund springt um einen Ball zu fangen , während ein anderer zusieht .
#
# Ein blondes Kind schaukelt auf einer Schaukel .
#
# Ein Mann und zwei Frauen diskutieren und trinnken Weißwein
#
# Ein Asiate bereitet im Freien Essen zu .
#
# Ein brauner Hund ist kurz davor , einen Frisbee zu fangen .
#
# Fans jubeln während die Band ein Lied spielt .
#
# Ein kleiner Junge steht neben einer Pyramide aus Sand .
#
# Drei kleine Kinder gehen durch einen grasbewachsenen Hof .
#
# Ein Mann grübelt über einer Skulptur auf einem Wagen .
#
# Ein Mann fährt auf einem Berg Fahrrad .
#
# Ein Junge in blau @-@ gelben Gummistiefeln läuft auf Erde .
#
# Eine Frau in einer orangefarbenen Jacke sitzt auf einer Bank .
#
# Ein Mann macht einen Trick auf dem Skateboard
#
# Ein Mann in einem Karateanzug in der Luft .
#
# Eine Frau verkauft auf einem Gehsteig Tüten mit Früchten .
#
# Zwei Fußballmannschaften auf dem Feld .
#
# Ein Kind in einem blauen Shirt springt von einer Bank .
#
# Ein Torwart in einem gelben Trikot schützt das Tor .
#
# Eine Gruppe junger Menschen trinkt Shots in einem Mexikanischen Setting .
#
# Ein Junger Mann rutscht mit dem Skateboard über ein rosa Geländer .
#
# Ein kleiner Junge springt von einem Stockbett auf ein kleineres Bett .
#
# Zwei Leute in komischen Alienkostümen , eines blau und eines purpurn , stehen auf einer Straße .
#
# Ein Läufer in einem blauen Shirt mit einer aufgeklebten Nummer .
#
# Ein asiatischer Fabrikarbeiter posiert für die Kamera .
#
# Ein Mann , der anscheinend bei einem Marathon mitläuft , zeigt zwei Daumen nach oben .
#
# Basketballspieler versuchen während eines Spiels , einen Korb zu erzielen .
#
# Ein Footballspieler in einem orangefarbenen Trikot lächelt und hält einen Football .
#
# Zwei Downhill @-@ Skateboarder fahren um eine Kurve während andere zusehen .
#
# Ein Team in Weiß und Gold an der Seitenlinie eines Footballfeldes .
#
# Ein kleines Mädchen schiebt seinen Roller über eine Wiese mit Bäumen .
#
# Eine Gruppe asiatischer Kinder in weißen Hemden und Kappen gibt eine Vorstellung vor einer Menge .
#
# Fußgänger auf einer Straße blicken auf ein Kind in einem Karton .
#
# Ein brauner Hund läuft über den Sandstrand .
#
# Zwei Männer in Armeeuniform stehen neben einer Frau .
#
# Der Dalai Lama bei einem Empfang , zu dem Besucher Nelken , Schirme und Gebetsfahnen bringen .
#
# Ein Radfahrer springt über eine Hindernis .
#
# Ein Paar sitzt auf weißen Gartenstühlen und lächelt in die Kamera .
#
# Kleine Kinder fahren in einem Miniaturzug .
#
# Ein Surfer beim Wellenreiten in einem blauen Neoprenanzug .
#
# Ein Junge springt auf seinen Fußball spielenden Bruder .
#
# Zwei junge Männer aus verschiedenen Fußballmannschaften versuchen auf einem Fußballplatz den Ball zu bekommen .
#
# Leute gehen auf einer befestigten abschüssigen Straße , umgeben von Chinesischen Händlern .
#
# Ein kleiner Junge in weißen Hosen springt von der Couch .
#
# Ein Junge in einem orangefarbenen Shirt schüttet Legosteine aus einer Tasche .
#
# Eine Frau in braunen Sandalen , blauen Jeans und einem weißen Shirt hält ein Baby unter einem großen Baum .
#
# Drei Personen lächeln und halten politische Schilder .
#
# Ein Polizist steht neben einem Auto auf einer städtischen Straße .
#
# Zwei Männer mit Mützen .
#
# Ein Junge ist in der Luft und versucht einen Fußball zu treffen
#
# Ein kleiner Junge mit einer blauen Beanie @-@ Mütze hält den Kopf gesenkt .
#
# Ein rothaariger Mann mit Dreadlocks sitzt und spielt auf einer akustischen Gitarre .
#
# Ein Mann isst ein Sandwich und hält seine kleine Tochter auf dem Schoß .
#
# Ein afroamerikanisches Kind hält etwas hoch , worauf die Leute auf dem Bild stolz sind .
#
# Eine Frau gibt einer Gruppe Anweisungen über einen Lautsprecher .
#
# Kostümierte Zuschauer sehen zu wie ein Polizist eine Rede hält und ein Mann im Anzug eine Schale mit Obst hält .
#
# Eine Gruppe ist in einer Bar .
#
# Ein Mädchen in Weiß und eines in Grün gehen an einer blauen Autowaschanlage vorbei .
#
# Ein Mann verwendet elektronische Geräte .
#
# Eine Person surft auf einer brechenden Welle auf dem Ozean .
#
# Ein Armeeoffizier inspiziert etwas .
#
# Eine Braut und Bräutigam küssen sich unter dem Brautschleier .
#
# Bereitschaftspolizei steht im Hintergrund während ein junger Mann mit einem roten Schal über dem Gesicht vorbeigeht .
#
# Ein schwarz @-@ weißer Hund springt bei einem Wettbewerb über ein Hindernis
#
# Eine Frau in einer Strickjacke liest zu Hause ein Buch .
#
# Mehrere Teenager blicken über ein Geländer in einem dunklen Raum .
#
# Der Mann im weißen T @-@ Shirt macht sich daran , auf einen Fels zu klettern .
#
# Ein Teenager streckt sich in der Küche und sein Bauch ist teilweise sichtbar .
#
# Personen halten verschiedene Arten von Trommelschlägeln über unterschiedliche Trommeln .
#
# Drei Farmer ernten Reis auf einem Feld .
#
# Zwei Frauen und ein Mann betrachten ein Buch .
#
# Die Beine von drei Kindern , die neben einem Durcheinander verknoteter Fäden stehen .
#
# Ein Koch posiert beim Kochen für die Kamera .
#
# Viele Leute protestieren auf einer Straße gegen Kohlekraftwerke .
#
# Der Teenager springt mit seinem Fahrrad über den Hügel .
#
# Ein kleines Mädchen läuft entlang einer Küste .
#
# Eine weiße Ente schlägt im Wasser mit den Flügeln .
#
# Zwei Männer stehen vor dem Heck eines Lasters und hinter einem Metallgegenstand und unterhalten sich anscheinend während vier weitere Personen um sie herum stehen .
#
# Eine Frau in einem rosa Rock hält ein Baby .
#
# Ein Hockeyspieler in einem gelben Trikot schützt das Tor .
#
# Ein Mann läuft an einem Schild vorbei , auf dem E.S.E. Electronics steht .
#
# Drei Jungen in grünen Shirts und braunen Hosen posieren auf dem Oberteil einer Rutsche .
#
# Ein Mann tanzt mit einem Hund zwischen den Beinen .
#
# Der weiße Hund läuft im flachen Wasser .
#
# Schlagzeuger aus Oregon marschieren mit der Band .
#
# Eine Gruppe Kinder spielt in einem eingezäunten Hof während ein Erwachsener zusieht .
#
# Eine Gruppe Frauen spielt gemeinsam auf Musikinstrumenten .
#
# Ein kleines Mädchen in einem violett karierten Kleid liegt auf dem Boden und weint .
#
# Ein Mann mit ergrauenden Haaren rasiert seinen Bart.
#
# Zwei schwarze Hunde , ein schwarzer Welpe und ein weißer Hund im Schnee .
#
# Ein Mann in einem Basketballtrikot von Miami macht einen Sprungwurf .
#
# Eine Frau sitzt vor ihrem Haus mit einer blauen Tür und genießt die frische Luft .
#
# Kinder sitzen auf einem Mann in einem Bananenkostüm .
#
# Ein grauweißer Hund springt über stehendes Wasser im Sand .
#
# Eine Menschenmenge hat sich im Regen um einen Springbrunnen im Park versammelt .
#
# Mehrere ältere Männer , einige mit traditionellen Kopfbedeckungen , treffen sich an einer Straßenecke .
#
# Ein junger Hund , der aussieht wie Lassie , im Schnee .
#
# Der Fußballer im goldenen Trikot blockt den Ball vor dem gegnerischen Spieler .
#
# Eine Frau in einem schwarzen Hemd strickt mit rotem Garn .
#
# Vier Frauen asiatischer Herkunft tragen goldene Kleider und tanzen Ballett .
#
# Eine Person spielt auf einem einzigartigen Instrument .
#
# Ein Mädchen in schwarzer Sportbekleidung mit der Nummer 1102 auf dem Trikot läuft über einen Rasen .
#
# Ein Kind mit der Nummer " 93 " fährt Ski .
#
# Ein älterer Herr und ein junges Mädchen fangen an , gemeinsam ein Puzzle zusammenzusetzen .
#
# Ein Filmteam filmt einen afrikanischen Jungen in einem gelben Shirt .
#
# Eine beleuchtete Brücke mit einem Radfahrer und ein paar Autos .
#
# Ein Mann reitet auf einem Bullen in einem Gehege .
#
# Ein Junge springt hoch , um einen Tennisball mit seinem Schläger zu treffen
#
# Kinder klettern auf eine Wand während zwei weitere Personen zusehen .
#
# Menschen laufen über einen Universitätscampus mit Palmen im Hintergrund .
#
# Ein kleines Mädchen tritt in einem Karatekurs einen schwarzen Gegenstand .
#
# Zwei Männer versuchen sich aus dem Wasser auf einen Steg aus Autoreifen hochzuziehen .
#
# Eine Menschenmenge beobachtet zwei Männer beim Breakdancen .
#
# Eine professionell gekleidete Frau steht an einem Podium und debattiert oder diskutiert über etwas Wichtiges .
#
# Eine Frau liegt auf einem Sofa und lacht .
#
# Eine schwarze und eine weiße Frau wischen einen schmutzigen Boden .
#
# Ein Reh springt über einen Zaun .
#
# Drei Hunde spielen auf einem Feld .
#
# Zwei kleine Kinder auf dem Sand .
#
# Ein lächelnder Junge spielt im Laub mit den Enten .
#
# Diese vier Personen stehen mit 3 Hunden im Freien .
#
# Beim Besuch von Maya @-@ Ruinen zeigt ein Führer in Richtung weiterer Sehenswürdigkeiten .
#
# Ein Mädchen in einem Radio @-@ T @-@ Shirt mit offenem Mund
#
# Eine Gruppe Stammesangehöriger füllt in der Wüste Wasserbehälter .
#
# Ein Mann steht auf einer Straße in der Stadt .
#
# Ein Schwarm Vögel fliegt mit Futter in den Schnäbeln weg .
#
# Zwei Männer reiten über eine Farm und führen einen von einem Esel gezogenen Wagen .
#
# Zwei Männer stehen auf einem Berggipfel .
#
# Ein junges Mädchen hat Spaß während es einen Schneeengel macht .
#
# Drei Männer lächeln für die Kamera und zeigen ihre Muskeln .
#
# Eine Person schreibt auf einer Tafel in einem leeren Klassenzimmer .
#
# Ein Mann in einem schwarzen Shirt sitzt mit einem offenen Apple @-@ Laptop vor sich an einem Tisch .
#
# Vier Personen entspannen auf einem grasbewachsenen Hügel mit Ausblick auf ein felsiges Tal .
#
# Ein Junge auf einem Skateboard springt neben Eisenbahnschienen in die Luft .
#
# Ein Mann in einem orangefarbenen Shirt spielt Tennis .
#
# Der Hund mit dem roten Halsband knurrt den Hund mit dem blauen Halsband an .
#
# Der Junge ist im Freien und genießt einen Sommertag .
#
# Ein Arbeiter in einem orangefarbenen Arbeitsanzug kniet und inspiziert eine Maschine .
#
# Männer in Cowboyhüten stehen bei einem Rodeo herum .
#
# Zwei Hunde sind im Schnee , einer von ihnen hat etwas im Maul .
#
# Eine Arbeitnehmerin macht eine Pause , um etwas zu trinken .
#
# Ein beigefarbener Hund läuft hinter einem weißen Hund mit einem gelben Spielzeug .
#
# Hockeyspieler in weißem Trikot mit einem Schläger .
#
# Mann in einem weißen Hemd und Golduhr spielt mit einer Platine .
#
# Ein schwarzes Pferd steckt seinen Kopf durch einen Zaun und versucht , an das Gras zu kommen .
#
# Ein Crack @-@ Opfer tut so , als würde es seine Hände aufwärmen wollen , raucht aber in Wahrheit Crack .
#
# Zwei Typen und eine Frau lächeln .
#
# Ein Kind beugt sich über eine Auslage aus blauem und gelbem Plastik während eine Erwachsener zusieht .
#
# Ein schwarz @-@ weißer Hund läuft zu einem kaputten Ball im Schnee .
#
# Ein junges Mädchen steht neben einer gelben Katze auf einer Küchenarbeitsplatte .
#
# Die zwei Kinder Spielen auf dem Spielplatz .
#
# Ein Tennisspieler in einem grün gestreiften Shirt hält seine Hand vor den Mund .
#
# Ein Junge in einem roten Badeanzug spielt im Wasser .
#
# Ein Kind mit roter Jacke und Mütze hält ein großes Stück Schnee .
#
# Zwei Polizisten in orangefarbenen Warnwesten stehen mit Passanten vor einem weißen Zelt .
#
# Zwei Personen stehen neben einem Baum .
#
# Zwei Männer sitzen und unterhalten sich neben einem Gebäude aus Stein .
#
# Ein brünettes Kind mit Brille hält ein blondes Kind in einem roten Sweatshirt und gelben Stiefeln .
#
# Ein schwarz @-@ weißer Hund spielt mit einem weißen Ball .
#
# Zwei Personen küssen sich auf einem Gehsteig vor eine Limousine während Leute vorbeigehen .
#
# Eine Frau spielt Volleyball .
#
# Zwei große Hunde kämpfen auf einem unbefestigten unbewachsenen Gelände .
#
# Ein brauner Hund springt über eine Hürde .
#
# Ein Mann in einem gestreiften Shirt raucht auf der Straße eine Zigarette .
#
# Ein kleines Mädchen hält einen kleinen Jungen auf ihrem Schoß .
#
# Ein Mann versucht an einem schönen Samstagnachmittag , einen sehr wütenden Bullen zu reiten .
#
# Kinder bemühen sich , beim Seilziehen zu gewinnen .
#
# Ein Radfahrer lehnt sich auf einer unbefestigten Piste mit einem Mountainbike in die Kurve .
#
# Zwei Personen und eine angebundene Kuh vor einem Haus .
#
# Der kleine Junge lernt mit seinem Vater , Rad zu fahren .
#
# Ein Junge in einem roten Shirt und schwarzen Shorts kehrt eine Einfahrt .
#
# Eine afrikanische Familie steht vor ein paar provisorischen Behausungen .
#
# Ein Mann spielt neben einem Baum ein Instrument .
#
# Zwei Frauen halten sich über einen Tisch an den Händen und lächeln in die Kamera .
#
# Ein hechelnder brauner Hund geht auf dem Gras .
#
# Eine Baseballspielerin in einem schwarzen Shirt fängt eine Spielerin in einem weißen Shirt .
#
# Eine Frau hält einen großen Scheck für " Kids ' Food Basket " .
#
# Die zwei Hunde , einer mit einem Tennisball im Maul , laufen durch hohes Gras .
#
# Zwei Erwachsene und zwei Kinder sitzen auf einer Parkbank .
#
# Eine Frau bläst eine Pusteblume auf einer Wiese .
#
# Ein Mann verkauft Kartoffeln an eine Gruppe .
#
# Eine Gruppe versammelt sich auf einer Straße um einem Akkordeonspieler zuzuhören .
#
# Ein Mann sitzt auf einer Bank und hört Musik auf seinem iPod .
#
# Ein alter Mann in dicker Kleidung sitzt in der U @-@ Bahn und liest eine Zeitung .
#
# Ein älterer Mann mit Brille bereitet Fleisch zu .
#
# Ein Mann macht einen Trick auf dem Fahrrad , bei dem er auf dem Hinterreifen balanciert .
#
# Ein Mann ist am Strand und macht eine Sandskulptur .
#
# Mehrere Menschen essen an einem Picknicktisch im Park .
#
# Zwei Frauen werden bei einer Art Baumaßnahme an einem Baum festgeschnallt .
#
# Ein Cowboy versucht beim Rodeo , die 8 Sekunden zu schaffen .
#
# Ein Hund springt durch ein brennendes Hindernis .
#
# Eine übergewichtige Frau mit langen schwarzen Haaren in einem rosa Shirt mit Namensschild trägt Lippenstift auf .
#
# Ein Mann repariert das Fahrrad eines kleinen Mädchens .
#
# Zwei Mädchen in bauschigen Kleidern tanzen vor ein paar Musikanten auf der Straße .
#
# Der gelbe Hund trägt einen Stock übers Wasser .
#
# Ein Mädchen in einem Sweatshirt verdeckt die Sonne .
#
# Ein Rockkonzert findet statt .
#
# Drei Frauen in leuchtenden Farben und mit Kopfbedeckungen halten Karten mit Liebesbotschaften .
#
# Ein brauner Hund gräbt im Dreck .
#
# Ein kleiner Junge in einem weiß gestreiften Shirt und mit einem Stirnband hält einen Tennisschläger .
#
# Zwei Hunde laufen im Wald weg von der Kamera .
#
# Ein Mädchen spielt komplett bekleidet im Springbrunnen .
#
# Drei junge Sumoringer stehen und hören einem Ansager zu
#
# Zwei männliche Wanderer inspizieren einen Baumstamm , der am Rand eines Waldweges liegt .
#
# Drei Spieler bringen einen gegnerischen Spieler zu Boden .
#
# Zwei Jungen überqueren eine Straße in einer Stadt während sie mit einem roten Fußball spielen .
#
# Ein Mann hält einen anderen mit seinem Rücken hoch .
#
# Weißer Hund auf einem Berg dreht sich zu etwas außerhalb des Bildes um , Himmel im Hintergrund .
#
# Ein Junge fährt Skateboard auf einer Skateboardrampe .
#
# Ein Musiker mit langen Haaren spielt Keyboard .
#
# Drei Sportler halten Blumensträuße und stehen auf dem Siegerpodest .
#
# Zwei glatzköpfige Drag Queens in roten Kleidern .
#
# Ein kleiner Junge hängt von einer Kleiderstange .
#
# Ein kleines Mädchen in Pink hält sich an einer Stange fest .
#
# Ein Mann in Grün springt auf seinem Motorrad über mehrere andere Motorräder .
#
# Eine Frau spielt im Park mit zwei kleinen Jungen .
#
# Vier Personen spielen Fußball auf einem Strand .
#
# Zwei Teenagerinnen umarmen sich vor Radfahrern im Hintergrund , eine trägt einen Fahrradhelm .
#
# Zwei mittelgroße Hunde laufen über den Schnee .
#
# Eine Frau steht auf einem grünen Feld , hält einen weißen Hund und zeigt auf einen braunen Hund .
#
# Ein Tisch voller gerahmter Bilder , ein Freiluftmarkt .
#
# Zwei Personen sitzen gegen eine Wand gelehnt an einem Tisch im Freien und machen Grimassen .
#
# Zwei Typen mit gepiercten Brustwarzen lächeln .
#
# Ein Kind liegt auf einem beigefarbenen Teppich und lacht .
#
# Ein Mann und eine Frau sitzen , fein gekleidet und mit eingehakten Armen .
#
# Zwei Frauen beim Schlammringen in einem Kinderbecken .
#
# Ein Typ in einem weißen Shirt schlendert mit einem Drink in der Hand .
#
# Die Silhouetten von zwei Personen auf einem See , der einen bunten Himmel reflektiert .
#
# Mehrere formell gekleidete Personen sitzen an einem Tisch .
#
# Zwei Mädchen ( eine in Blau und die andere in Pink ) liefern sich ein Rennen auf Rollschuhen .
#
# Die vier Personen sitzen auf einem Haufen von Steinen .
#
# Eine Gruppe macht Tricks auf Motorrädern .
#
# Radfahrer in Rennmontur fährt durch ein Waldgebiet .
#
# Ein Mann in einem grünen Shirt spaziert am Strand mit seinen Turnschuhen in der Hand .
#
# Mehrere Männer stehen um ein antikes Rennauto herum .
#
# Zwei Männer arbeiten unter der Haube eines weißen Rennautos .
#
# Kinder Springen vom Rand in einen Pool .
#
# Ein Mann steht am Rand einer Mauer und fällt gleich runter .
#
# Eine Frau in einem gestreiften Outfit auf einem Fahrrad .
#
# Ein schwarz gekleidetes Mädchen posiert für die Kamera .
#
# Ein Mann in Shorts steht am Wasser .
#
# Vier schwarze Männer sitzen auf den Stufen einer Kirche .
#
# Ein Kran arbeitet mitten in einem Schutthaufen .
#
# Eine Turnerin in Rot und Weiß in der Drehung auf einem ungeraden Balken .
#
# Eine ältere Dame in einem grünen Sweatshirt wählt Gemüse aus .
#
# Zwei Männer stellen in einer Werkstatt mit Werkzeugen Gegenstände her .
#
# Eine Lehrerin in Weiß und ein kleines Mädchen in einem gelben Kleid spielen mit Bauklötzen .
#
# Ein kleines Kind schläft in seinem Bett mit einem offenen Buch auf der Brust .
#
# Eine Frau isst an einem schönen Tag auf dem Gras .
#
# Ein Mann geht auf einer Kopfsteinstraße neben Gebäuden mit roten Dachtraufen .
#
# Eine Frau mit einem Hut macht Brot .
#
# Eine einzelne Frau verwendet einen großen einfachen Stößel und Mörser , um Pflanzenmaterial zu zerdrücken , während sie auf einem Stoppelfeld steht .
#
# Ein Mann in einem Karateanzug macht eine Vorführung vor zwei Punktrichtern .
#
# Ein formell gekleideter Mann spielt Klavier auf dem Gehsteig an einer städtischen Straße .
#
# Ein älterer Mann sitzt in einem Stuhl und isst ein paar Snacks .
#
# Eine Frau in einem weißen Hemd arbeitet hinter dem Tresen in einem Café .
#
# Ein Mann in Arbeitskleidung steht auf der Ladefläche seines Lasters .
#
# Zwei Kinder beobachten Pferde durch einen kleinen Zaun .
#
# Ein Fenster mit einem aufgemalten Design .
#
# Eine Frau in einem knallrosa Mantel steht vor einer Vitamin Shoppe @-@ Filiale und macht eine Grimasse in Richtung einer Frau in einem violetten Mantel .
#
# Ein Cowboy bandagiert seinen Arm .
#
# Ein Mann in einem gelben Hemd und ein Mann in einem dunkelblauen Hemd unterhalten sich .
#
# Drei asiatische Kinder sitzen auf einer Couch mit Wandteppichen im Hintergrund .
#
# Ein Mädchen in einem roten Shirt springt hoch , um einen Tennisball zu treffen .
#
# Ein Mann posiert für die Kamera mit einem grünen Kran .
#
# Ein Mann stößt in einem Restaurant lächelnd mit einer anderen Person an .
#
# Ein Mann lädt gebackene Brezeln auf einen Koffer @-@ LKW .
#
# Ein Mann in einer schwarzen Jacke spielt in der Öffentlichkeit Gitarre .
#
# Eine Tanztruppe bei einer Aufführung während einer Parade in China .
#
# Ein Mann steht auf einem steinigen Abhang und blickt auf ein Gewässer .
#
# Ein Polizist beobachtet eine Frau beim Aussteigen aus dem Bus .
#
# Zwei Polizisten mittleren Alters beobachten nachts einen Parkplatz .
#
# Zwei Männer in blauen Hemden sehen sich ein Fußballspiel an .
#
# Eine Gruppe von Männern in blauen Uniformen stehen zusammen .
#
# Eine junge Dame macht Yoga am Strand .
#
# Eine große Menschenmenge steht in einem Park herum und einige spielen auf Instrumenten .
#
# Ein Mann mit einem Luftballon , der Ballontiere macht .
#
# Ein Mann , der über einem Grill im Freien Fleisch grillt .
#
# Zwei Männer verkaufen Obst auf einem Obstmarkt .
#
# Eine brünette Frau in einem weißen Bikini gießt einem Mann einen Drink ins Glas .
#
# Ein Junge mit Sonnenbrille läuft hinter einem Rummelplatz .
#
# Eine Hand mit Handschuh hält etwas , was wie ein übergroßer Nagel aussieht , an einen Holzklotz .
#
# Ein Mann in einem karierten Hemd zeigt ein schwarzes Paar Handschuhe .
#
# Zwei Männer auf weißen Plastikstühlen sitzen in einem Eingang .
#
# Ein junges Mädchen in einem roten Kleid trägt einen schwarzen Cowboyhut .
#
# Mann in einem rot @-@ weißen Fußballtrikot steht an der Seitenlinie mit einem gelb @-@ blauen Fußball .
#
# Leute springen an einem Seil über eine Gletscherspalte .
#
# Leute sehen zu während Marathonläufer vorbeilaufen .
#
# Leute mit Laptops vor einem großen Fenster .
#
# Ein DJ bei der Arbeit wird von Scheinwerfern angestrahlt .
#
# Ein Mann mit Handschuhen trägt Mais durch ein Feld .
#
# In einem Café wird von einer Spiegelreflexion ein Foto gemacht .
#
# Eine muslimische Frau hält Luftballons bei einer muslimischen Veranstaltung .
#
# Eine Frau sitzt in einem Käfig mit einer Katze und zwei Kaninchen .
#
# Eine Frau sitzt gegen eine Ziegelwand gelehnt in einem Gebäude .
#
# Drei junge Frauen sitzen sich auf roten Plüschstühlen gegenüber .
#
# Eine Frau in einem blauen Shirt spaziert in einem Dorf .
#
# Sechs Kinder sitzen mit Blöcken und Stiften auf einer Stufe .
#
# Ein brauner Hund spielt am Ufer mit einem Stock .
#
# Zwei Hunde beißen spielerisch einen dritten Hund , dessen Zunge heraushängt .
#
# Ein Kind sitzt lächelnd auf dem Motorrad .
#
# 6 Personen versammeln sich zu einem großen Abendessen .
#
# Santa Claus wird bei einem Medienevent zu Weihnachten fotografiert .
#
# Militärangehörige marschieren an einem regnerischen Tag durch New York .
#
# Eine Frau in roten Hosen und mit einem blauen Helm fährt Fahrrad .
#
# Mehrere Männer in Kampfsportuniformen machen gemeinsam Bewegungen .
#
# Eine junge Frau und ein Mann in Kriegerkostümen hantieren vor einer Gruppe im Hintergrund mit Schwertern .
#
# Ein uniformierter Mann geht auf einer Straße mit zwei Autos und einem Baum .
#
# Junge Frau klettert auf Felswand
#
# Ein älterer Mann in einem hellblauen Mantel arbeitet am Straßenrand an einem Auto .
#
# Personen betrachten mehrere farbige Papierstücke auf einem Tisch .
#
# Ein Mann singt und spielt Gitarre in ein Mikrofon .
#
# Zwei Männer sitzen in einem Restaurant .
#
# Zwei Frauen in Shorts laufen auf einem Strand entlang des Wassers .
#
# Arbeiter diskutieren neben den Schienen .
#
# Ein Ausblick auf eine Fußgängerzone mit einem Mann in einer schwarzen Schürze und weißen Baseballmütze , der in der Mitte des Bildes steht .
#
# Eine Gruppe spielt an einem Gegenstand .
#
# Ein kleines Mädchen in Blau klettert auf der Straße auf ein Metallgeländer .
#
# Eine Gruppe von Männern sitzt und unterhält sich hinter grünen Früchten .
#
# Ein Typ in einem gelben Outfit steht hinter dem Mikrofon in einem Zelt .
#
# Ein brauner Hund mit einem lilafarbenen Frisbee im Mund .
#
# Ein Mann , der aussieht als würde er Kampfsportübungen machen , vor schlammig aussehendem Wasser .
#
# Eine Frau mit einem Getränk und eine Frau mit einem Mobiltelefon .
#
# Ein Kind in einer roten Jacke winkt mit einer Hand während es neben einem Plastikschlitten im Schnee liegt .
#
# Eine Frau sitzt neben ihrer Tasche und sieht Hunden im Park zu .
#
# Drei Männer stehen auf einer Bühne , einer von ihnen trägt Clown @-@ Makeup und hält eine Gitarre .
#
# Eine Frau verarbeitet Pflanzensaft in einem Stammesdorf
#
# Die Frau im roten Kleid tanzt mit dem Mann im Anzug .
#
# Zwei kleine Hunde folgen einem größeren Hund mit einem Tennisball
#
# Ein Mann mit buschigem Bart und Baseballmütze sitzt auf einer Parkbank .
#
# Ein afrikanischer Stamm steht im Garten mit dem Wald im Hintergrund .
#
# Ein junges Mädchen versucht , eine Ziege zu bürsten .
#
# Asiaten sitzen in einem Restaurant mit gelben Stühlen .
#
# Ein Baby sitzt mit Lätzchen in einem Hochstuhl und isst einen Keks .
#
# Ein grauhaariger Mann mit schwarzen Handschuhen mäht den Rasen .
#
# Eine Frau sitzt in einer Reihe aus roten Stühlen und liest ein Buch .
#
# Ein Kind sitzt auf den Schultern einer Frau und klatscht .
#
# Eine Familie geht auf dem Gehsteig durch den Schnee während am Rand ein Mann mit seinem Papierbecher sitzt .
#
# Eine Katze sitzt auf einem Werbeschild .
#
# Ein Mann in einem pinken Shirt und schwarzer Jacke mit Kopfhörern .
#
# Ein junger Mann wirft einen Football .
#
# Ein Typ und ein Mädchen gehen einen spiralförmigen Fußweg hinunter .
#
# Eine Frau mit pinken Haaren beugt sich auf dem Gehweg hinunter und hält zwei pinke Hunde .
#
# Ein Mann im Anzug hält ein Getränk in einem Becher während er auf dem Gehweg an einem städtischen Bus vorbeigeht .
#
# Mann springt vor einer Felsformation im Hintergrund .
#
# Eine Person in einer roten Jacke und schwarzen Hosen hält Regenbogenbänder .
#
# Eine Frau legt den Arm um eine Person im Rollstuhl .
#
# Ein Mann in einer weißen Schürze bereitet für eine Frau in einer weißen Jacke im Freien in einer Pfanne etwas mit Eiern zu .
#
# Eine Frau mit einem Push @-@ to @-@ Talk @-@ Mobiltelefon und einem Headset wartet an einem Zebrastreifen .
#
# Eine Gruppe von Männern geht auf einer städtischen Straße .
#
# Eine Straße neben einem interessanten Ort mit vielen Säulen .
#
# Eine Gruppe von Personen in Schwarz steht an einem Dock nahe eines großen Gebäudes .
#
# Ein Mann mit ein paar Kisten Bier .
#
# Ein Mann mittleren Alters sitzt und spielt Akkordeon .
#
# Mädchen mit grünem Pulswärmer , Haargummis und Ohrringen steht im Freien .
#
# Ein junges Mädchen in einem pinken Oberteil ist am Strand und läuft in Richtung des Ozeans .
#
# Ein Skateboarder in einem schwarzen T @-@ Shirt und Jeans fährt durch die Stadt .
#
# Ein Mann in einer Jacke macht Fotos von einem großen Gebäude .
#
# Menschen an der Seitenlinie bei einem Fußballspiel .
#
# Auf diesem Foto eilt eine vierköpfige Familie über eine geschäftige Straße in der Stadt .
#
# Eine Menschengruppe läuft bei Sonnenschein die Straße hinunter .
#
# Eine Straße bei einer Ampel mit mehreren Personen , darunter ein Mann in einem braunen Mantel und Sonnenbrille , der seine Hand ans Gesicht hält .
#
# Ein paar Pflanzen wachsen beim Fenster .
#
# Dieser Spieler mit dem blauen Helm war in einem Baseballspiel zwischen zwei Teams gerade am Schlagmal und ist gerade mit dem Schlagen fertig .
#
# Die Frau im goldenen Mantel beeilt sich , um die U @-@ Bahn zu erwischen .
#
# Einige Leute sitzen auf Bänken unter Reihen von Bäumen vor einem Gebäude .
#
# Ein Mann im Anzug sitzt an einer Bushaltestelle .
#
# Ein afroamerikanischer Mann ist umgeben von umgedrehten weißen Eimern und dunkleren Kisten und drückt sich über eine handgeschriebene Nachricht auf einem Stück Karton aus .
#
# Eine junge brünette Frau isst und trinkt etwas .
#
# Ein Mann in einem Anzug und mit Hut spielt auf der Straße Gitarre .
#
# Eine Frau in einer roten Weste arbeitet am Computer .
#
# Personen stehen um Räucherstäbchen herum und wedeln sich den Rauch ins Gesicht .
#
# Ein Mann verwendet den Badezimmerspiegel , um seine Krawatte zu binden .
#
# Mehrere Personen spielen Musik während eine gut gelaunte Menge sitzt und zuhört .
#
# Zwei junge Männer fahren auf einem sehr kleinen Wagen voller Kartoffeln , der von einem Pferd gezogen wird .
#
# Eine Frau in einem Klid geht auf der Straße an einer Baustelle vorbei .
#
# Ein Mitarbeiter in einem Laden fragt einen Kunden , der Alkohol kauft , nach seinem Alter und einem Ausweis .
#
# Ein Mann mit Sonnenbrille bedient ein Baufahrzeug und lädt Kies auf den Boden ab .
#
# Ein Baby spielt mit seinem Spielzeug und betrachtet eine schwarz @-@ weiße Katze .
#
# Eine Teenagerin trägt eine Gitarre im Wald .
#
# Ein Mann mit einem Rucksack geht eine Straße hinunter .
#
# Zwei Männer unterhalten sich vor einem Souvenirgeschäft in Rom .
#
# Ein Frau in Schwarz hält etwas im Mund .
#
# Eine Gruppe von Leuten sitzt im Freien um einen kleinen , kurzen Tisch .
#
# Ein Mann fährt sein Fahrrad die Rampe hoch .
#
# Eine Frau in einem schwarzen Tank @-@ Top mit einem Kreuz @-@ Halsband blickt kurz vor Sonnenuntergang in die Ferne .
#
# Drei junge Mädchen gehen gemeinsam auf dem Gehsteig .
#
# Eine Frau mit langen Haaren bei einer Abschlussfeier .
#
# Ein Mann fährt auf einer Straße Skateboard während ihm ein anderer Mann vom Gehsteig aus zusieht .
#
# Ein Mann in einer schwarzen Lederjacke steht vor einem Schild .
#
# Ein Mann und eine Frau singen gemeinsam im Freien .
#
# Ein junges Mädchen mit gelockten blonden Haaren in einem weißen Top liegt im Gras und hält einen Blumenstiel .
#
# Eine Frauenfußballmannschaft in grünen Trikots macht eine Dehnübung .
#
# Eine Frau spielt in der Öffentlichkeit eine dramatische Szene hinter gelbem Absperrband .
#
# Ein Mann bückt sich und macht Hausarbeiten während im Hintergrund Tauben vorbeilaufen .
#
# Eine Gruppe von Männern steht auf einem Feld aus schwarzen Bällen .
#
# Ein geschäftiger Tag auf einem städtischen Platz .
#
# Ein Mann mit einer Zigarette im Mund macht sich einen Teller mit Essen .
#
# Zwei Gruppen von Schwimmern waten ins Wasser .
#
# Menschen sitzen auf einer Bank auf einem Platz in der Stadt während in der Nähe zufällige Gegenstände wie eine Lampe und ein Mannequin stehen .
#
# Die Arbeiter stehen um ein Loch mit einem Eimer herum .
#
# Ein Mann ohne Hemd in schwarzen Shorts steht an einer felsigen Küste neben einem großen Gewässer .
#
# Ein Wachmann hält Wache während seiner Schicht .
#
# Leute spielen Pool , einer davon ist ein Mann in einem blauen Hemd , der Rest sind Frauen , deren Köpfe allerdings nicht im Bild sind .
#
# Leute stehen vor einer von Wasser umgebenen Skulptur .
#
# Eine Frau sieht zu , während ein Mann mit verschränkten Armen spricht .
#
# ...
#
# Ein Mann in einem smaragdgrünen Hemd liest eine Zeitung .
#
# Ein Junge in einem Rutschfahrzeug trägt ein grünes Shirt und hält ein Buch .
#
# Zwei Kinder sitzen nebeneinander und essen Süßigkeiten .
#
# Radfahrer auf der Straße , alle tragen Helme .
#
# Menschengruppen , die alle Fahrrad fahren .
#
# Ein Mann sitzt auf einer Plattform mit Rädern und wird von einem Esel gezogen .
#
# Ein Mann fährt auf einem Fahrrad durch einen Torbogen .
#
# Ein bunt gekleideter junger Mann mit sichtbaren Hautverletzungen sitzt und raucht eine Zigarette .
#
# Zwei Männer in Anzügen unter einem Regenschirm vor einem Graffiti .
#
# Ein dünner alter Mann trägt ein schmutziges weißes Hemd und fährt Fahrrad auf der Straße .
#
# Ein Mann versucht , einen jungen Stier von einem Pferd aus mit dem Seil zu fangen .
#
# Ein Cowboy versucht von einem Pferd aus ein Kalb mit dem Lasso zu fangen .
#
# Zwei Radfahrer mit Helmen fahren an ein paar abgeernteten Feldern vorbei .
#
# Ein Mann beugt sich zur Seite und zieht etwas aus einer Tasche .
#
# Ein Mann fährt in einem motorisierten Wagen vorbei , um den Park zu sehen .
#
# Eine tätowierte Person betrachtet ein Foto auf einer Digitalkamera oder einem Handy .
#
# Ein Mann in einem schwarzen Hemd und Jeans steht auf dem Gehsteig und blickt in die Kamera .
#
# Ein Junge und ein Mädchen stehen gemeinsam auf dem Gehsteig und betrachten einen Gegenstand .
#
# Mehrere Personen in blauen Kitteln und eine in einem Rock und schwarzer Bluse .
#
# Eine Frau und eine Hund sitzen auf einer weißen Bank in der Nähe eines Strandes .
#
# Zwei Frauen gehen auf der Erde vor einem Gebäude .
#
# Eine Gruppe von Männern und ein Kind in weißen Shorts stehen auf der Straße .
#
# Eine ganz in schwarz gekleidete Frau trägt auf dem Gehsteig eine schwarze Tasche .
#
# Gruppe von Männern sitzt an einem Tisch und unterhält sich .
#
# Ein Wandgemälde auf einem Gebäude .
#
# Ein asiatischer Mann mit Handschuhen arbeitet an einem Imbissstand .
#
# Frau sitzt an einem Tisch und arbeitet an ihrem Laptop .
#
# Eine Person sieht zum Computer auf einem Tisch mit einem Telefon und einer Schachtel .
#
# Ein Mann sitzt in einem Stuhl und beobachtet Leute , die vorbeigehen .
#
# Zwei Personen mit Hüten stehen auf einem Feld und pflegen Nutzpflanzen .
#
# Jemand springt in Barcelona über ein Reck .
#
# Ein Mann in Stiefeln und einem Cowboyhut sitzt auf einem springenden Pferd während Zuschauer auf den Tribünen sitzen .
#
# Zwei junge Mädchen sitzen auf der Straße und essen Mais .
#
# Drei Kinder in Footballtrikots zweier verschiedener Mannschaften spielen Football auf einem Footballplatz während ein weiterer Spieler und ein Erwachsener im Hintergrund stehen .
#
# Ein kleines Kind mit schmutzigem Gesicht wird von einer alten Frau gehalten .
#
# Ein Mann mit Brille blickt in die Kamera während ein anderer Mann in einem blauen Hemd sich auf etwas konzentriert .
#
# Zwei Personen sitzen unter einem Baum mit grünem Gemüse .
#
# Ein kleiner Junge mit einer blauen Mütze blickt durch ein Teleskop während ein anderer Junge zusieht .
#
# 3 Männer kochen in einer kleinen Küche .
#
# Ein junges Mädchen in einem grauen Schneeanzug fährt Ski auf einem verschneiten Berg .
#
# Eine Gruppe von Dorfbewohnerinnen versammelt sich beim Tanz .
#
# Ein Mann und eine Frau sortieren Wäsche mit Latexhandschuhen .
#
# Ein junges Mädchen sitzt auf einem Holzstuhl .
#
# Zwei Arbeiter verschweißen die Stangen eines Zauns an einer viel befahrenen Vorstadtstraße .
#
# Ein junger Mann mit langen Haaren fährt an einem bewölkten Tag Skateboard auf dem Geländer .
#
# Zwei Männer schaufeln auf einem Freiluftmarkt den Weg von Schnee und Matsch frei .
#
# Ein Typ in einem weißen Hemd spielt auf einer weißen Gitarre .
#
# Ein junges Mädchen zeigt seiner Freundin , wie man eine Einwegkamera verwendet .
#
# Ein kleiner Junge springt von einem Steg in einen See .
#
# Eine sehr unglücklich aussehende Dame mit einer grünen Maske beim Zahnarzt .
#
# Ein Mann mit einer orangen Jacke und blauem Mütze klettert auf einen verschneiten Berg .
#
# Ein kleines Mädchen mit blonden Haaren spielt und spritzt in einer Schlammpfütze .
#
# Ein Kind fährt auf einem Fahrrad durch eine Gasse mit einem Graffiti .
#
# Eine Turnerin wird bei einer Veranstaltung beurteilt .
#
# Menschen gehen auf einer Straße mit einem Straßenhändler .
#
# Ein Mann in traditionellem Gewand steht neben seinem Esel , der anscheinend auch bekleidet ist .
#
# Zwei Kinder spielen auf einem Fahrrad .
#
# Zwei Männer aus gegnerischen Mannschaften spielen Fußball auf einem Fußballplatz .
#
# Ein Mann springt in die Luft und posiert für Fotografen , die auf dem Boden liegen .
#
# Das Mädchen trinkt aus einem Springbrunnen .
#
# Der Hobbyhöhlenforscher findet auf seiner Wanderung Wasser .
#
# Ein Mann in einem Laborkittel blickt durch ein Mikroskop .
#
# Ein blondes Mädchen schläft auf einer braunen Couch .
#
# Ein Mann kehrt tagsüber den Gehsteig vor einem Ziegelbau .
#
# Drei Männer kochen in einer Küche .
#
# Ein Mann auf einem Gerüst vor einem Haus lächelt und posiert für den Fotografen .
#
# Zwei Mädchen in Shorts halten Händchen an einem Pool .
#
# Vier asiatische Kinder sitzen auf einer Bank und winken lächelnd in die Kamera .
#
# Kinder auf Fahrrädern in einem scheinbar verarmten Land .
#
# Ein kleiner Junge mit Kochmütze und Schürze schneidet in einer Küche Würstchen .
#
# Das ist ein Clown in einer Grundschule .
#
# Der Schiffskapitän lächelt und hält das Steuerrad seines hölzernen Schiffs .
#
# Ein gelber Bulldozer schafft Erdreich aus dem Weg .
#
# Eine Frau in einem roten Hemd reitet auf einem weißen Pferd , das an den Bäumen entlang galoppiert .
#
# Eine Frau sitzt vor Bäumen im Hintergrund auf einem sehr großen Stein und lächelt in die Kamera .
#
# Drei Männer in bunten Kostümen , Perücken und verrückten Sonnenbrillen gehen auf die Straße .
#
# Ein Mädchen spielt in einem kleinen Pool .
#
# Zwei Kinder , ein Junge in einem gelben Shirt und ein Mädchen in blau @-@ weiß gestreiften Klamotten , schaukeln .
#
# Ein Mann wirft ein Fischernetz in die Bucht .
#
# Ein Mann mit einem grauen Shirt , blauen Jeans und neongrüner Sicherheitsweste steht mit einem weißen Lieferwagen und einem weißen Gebäude im Hintergrund auf einer Bahnstrecke .
#
# Zwei Bauarbeiter legen Blech über Balken .
#
# Eine Band mit dezent in blau gekleideten Bandmitgliedern steht auf der Bühne .
#
# Ein Rocker mit freiem Oberkörper singt in ein Mikrofon während er Schlagzeug spielt .
#
# Ich sehe einen Mann , der die Artikel aus seinem Einkaufswagen nimmt um zu bezahlen .
#
# Der Mann mit dem Spazierstock macht einen Spaziergang .
#
# Eine Frau in einem weißen Pullover trainiert auf einem Crosstrainer .
#
# Ein Mädchen mit einer Maske reitet auf den Schultern eines Mannes durch eine Menschenmenge .
#
# Zwei Mädchen , eines älter und in Schwarz , das andere jünger und in Weiß , machen dieselbe Tanzbewegung vor einer Dekoration aus Ballons .
#
# Mehrere Frauen führen vor einem Gebäude einen Tanz auf .
#
# Ein glatzköpfiger Mann geht auf einem Gehsteig und telefoniert mit seinem Handy .
#
# Eine Frau spielt mit Fingerpuppen während ein kleines Kind in einem Kostüm vorbeigeht .
#
# Eine Gruppe von Leuten beobachtet junge Männer , die auf Eimern Schlagzeug spielen .
#
# Ein Mädchen mit gewöhnlicher und improvisierter Schutzausrüstung fährt Rollerblades .
#
# Ein kleines weißes Auto steht auf den Bahngleisen und wurde eventuell vom Zug im Hintergrund gerammt .
#
# Zwei Rocker singen und spielen auf einer dunklen Bühne .
#
# Ein Mädchen mit einer Baseballmütze , weißem T @-@ Shirt und blauen Shorts steht in einem von Wald umgebenen Gebirgsbach .
#
# Zwei Männer spielen Gitarre vor einem großen Publikum .
#
# Mehrere Leute tanzen vor diesem riesigen Haus mit ihren Partnern .
#
# Frau mit Hund verkauft ihre Ware im Freien auf den Treppen des alten Gebäudes .
#
# Eine Frau diskutiert mit zwei professionell gekleideten Männern .
#
# Eine Gruppe von Männern in roten und schwarzen Jacken sitzt auf Motorrädern und wartet .
#
# Ein Typ in einem weißen Trikot mit der Nummer 3 auf dem Rücken spielt Fußball .
#
# Ein Mann verkauft Snacks bei einer Sportveranstaltung .
#
# Zwei Männer vom grünen Team tackeln in einem Rugbymatch die anderen Spieler des schwarzen Teams , um an den Ball zu kommen .
#
# Kinder kämpfen um den Ballbesitz .
#
# Eine Person in Blau wirft auf einer Bowlingbahn als einzige ihre Kugel .
#
# Mehrere Fußballer auf einem Feld in Aktion .
#
# Junger Mann sitzt auf einem Skateboard , hält sein Handy und posiert auf der Rolltreppe .
#
# Eine blau gekleidete Frau läuft einen Marathon .
#
# Diese Band bereitet sich auf einen Auftritt vor Publikum in einer Kirche vor .
#
# Die # 8 von Iowa State streckt den Arm in Richtung eines Spielers der Texas AM beim Versuch , ihn zu tackeln .
#
# Zwei männliche Curler sind auf dem Eis und wischen den Pfad vor dem Stein , während eine kleine Menschenmenge zusieht .
#
# Männer spielen auf einem matschigen Platz Fußball .
#
# Ein Basketballspieler in Weiß geht in die Hocke während ein Spieler in Rot auf ihn zu läuft .
#
# Menschen gehen durch einen Torbogen in einer alt aussehenden Stadt .
#
# Zwei Rennautos , eines rot und das andere blau , fahren nebeneinander auf einer Rennstrecke während mehrere Personen zusehen .
#
# Ein Footballspieler in einem weißen Trikot hält einen Football .
#
# Ein sehr kleiner Junge guckt nach vorne während er in einen kleinen Gegenstand beißt .
#
# Eine Frau und ein Kind gehen eine Straße entlang .
#
# Ein Hockeyspiel wird vor großem Publikum gespielt .
#
# Drei Frauen springen im Gras auf Bällen .
#
# Ein afroamerikanischer Junge in blauen Shorts , einem schwarz @-@ roten Shirt und weißen Turnschuhen spielt Tennis .
#
# Ein Mann und eine Frau in weißen Shirts umarmen sich .
#
# Ein Mann mit einer Art Messsonde spricht mit einer Familie , die versucht , zu lächeln und freundlich zu sein .
#
# Sehr kleiner Junge in einem grünen Shirt liegt mit dem Gesicht nach unten auf einem weißen Bett .
#
# Ein Extremradfahrer ruht sich aus während im Hintergrund die Sonne untergeht .
#
# Eine warm gekleidete Frau fährt in einem verschneiten Gebiet Ski .
#
# Vier Mädchen und eine Frau lernen zu basteln .
#
# Ein Mann in schwarz @-@ weiß gestreifter Kleidung versucht , ein Pferd anzuhalten .
#
# Der Herr scannt das Bild , das ihm die Frau im blauen Hemd zeigt .
#
# Eine Frau mit roten Haaren steht bis zum Hals in trübem blauem Wasser .
#
# Zwei kleine Jungen posieren mit einem Welpen für eine Familienfoto .
#
# Vier Kinder üben Karate während zwei Erwachsene zusehen .
#
# Ein Mann liegt auf einem Sofa in einem Möbelhaus .
#
# Eine Gruppe von Leuten unterhält sich an Tischen .
#
# Zwei Jockeys , einer in rot @-@ blauen Karos und der andere in Orange und Braun , liefern sich ein Rennen vor einem verschwommenen Hintergrund .
#
# Das rote Auto fährt vor den beiden Autos im Hintergrund .
#
# Ein großer Stier versucht einen Mann bei einem Rodeo auf die Hörner zu nehmen während ein Rodeoclown herbeiläuft , um zu helfen .
#
# Ein Mann ohne Hemd geht zu einem gelben Kajak .
#
# Ein Junge zielt und schießt auf einem Schießstand .
#
# Zwei Jugendteams spielen Football im Sand .
#
# Ein Kind in Blau und ein Kind in Weiß stehen auf einer niedrigen Betonmauer neben einem Fluss .
#
# Eine Frau malt ein Blumenmuster auf einen Tontopf .
#
# Leute gehen auf einer belebten Straße in einem fremden Land .
#
# Ein rechtshändiger Pitcher der Saints wirft einen Ball .
#
# Zwei Männer , einer in Schwarz und Weiß und einer in Rot , spielen Beachvolleyball .
#
# Ein Mann steht in einem Boot und flickt Netze .
#
# Ein Surfer , der im Ozean beim Versuch , auf einer Welle zu reiten , von seinem Brett gefallen ist .
#
# Ein Techniker bereitet im Labor eine Probe vor .
#
# Fußballer springen in die Luft , um den Ball mit dem Kopf zu treffen .
#
# Zwei Jungen spielen gegeneinander Fußball .
#
# Eine ältere Person überquert die Straße mit einem Regenschirm in der Hand .
#
# Eine Gruppe von Läufern läuft auf zwei identische Wolkenkratzer zu .
#
# Ein Skateboarder fährt eine Betonwand hoch und fällt beinahe beim Versuch , einen Trick zu machen .
#
# Leute spielen ein Spiel im Pool .
#
# Ein Typ küsst einen anderen Typ
#
# Ein Mann schreibt einem kleinen Jungen ein Autogramm ins Buch .
#
# Ein junger Mann in einem blauen Shirt fährt in einer städtischen Gegend über ein Geländer .
#
# Ein Asiate sitzt mit Kisten von Erdnüssen auf der Straße .
#
# Ein britischer Gentleman in voller militärischer Uniform winkt mit seiner Mütze Leuten zu , die im Hintergrund sitzen und auf den Kanal blicken .
#
# Zwei Autos fahren auf einer Rennstrecke .
#
# Ein Mann in einem schwarz @-@ weißen Trikot hält gelbe Skistöcke und bereitet sich auf den Start vor .
#
# Zwei Personen liegen auf einem Rasen und küssen sich .
#
# Ein sehr kleines Kind mit einer Jeansmütze isst einen grünen Apfel .
#
# Die Footballspieler laufen , um den Ball zu fangen .
#
# Ein Mann mit kariertem Hut in einer schwarzen Jacke und einer schwarz @-@ weiß gestreiften Hose spielt auf einer Bühne mit einem Sänger und einem weiteren Gitarristen im Hintergrund auf einer E @-@ Gitarre .
#
# Ein Mann springt von einem Stier weg über eine Absperrung .
#
# Eine Frau in einem blauen Shirt und weißen Shorts spielt Tennis .
#
# Ein Mann spielt ein Intermezzo in einem Konzert .
#
# Ein Mann trägt eine große Ladung von Metallstäben auf seiner Schulter durch ein Holzlager .
#
# Frau mit Kamera wirft ihrem braunen Hund einen Frisbee zum Fangen zu .
#
# Die Silhouette eines Mannes und einer Frau , die ein großes Bonfire oder einen anderen großen , brennenden Holzgegenstand betrachten .
#
# Zwei Mädchen tauchen ihre Hände in einen Springbrunnen während Leute vorbeigehen .
#
# Ein nasses , lächelndes Kind ohne Hemd posiert mit seinen Armen in der Luft .
#
# Zwei Männer , einer in Weiß und einer in Blau , ringen .
#
# Eine Frau in einem roten Bikini springt beim Volleyball am Strand hoch , um einen Ball zu treffen .
#
# Kätzchen mit orangen Streifen beißt blondes Mädchen in die Nase .
#
# Eine Frau in einer gelben Schürze nimmt den Deckel von einem großen Topf .
#
# Zwei Kinder überqueren einen kleinen Bach über eine Steinbrücke .
#
# Zwei afroamerikanische Frauen fahren auf einem Moped auf einer städtischen Straße , die sich anscheinend in einem Großstadtgebiet mit Stau befindet .
#
# Zwei Jungen vor einem Getränkeautomaten .
#
# Radfahrer in Schwarz fährt auf einem Mountainbike einen unbefestigten Pfad hinunter .
#
# Eine Frau mit Tattoos macht mit ihrem Handy ein Foto von einem Gemälde .
#
# Eine überwiegend schwarz gekleidete Frau mit einem weißen Helm fährt vor verschwommenen Bäumen im Hintergrund Fahrrad .
#
# Ein Team von Radfahrern fährt um die Kurve während in Zuschauer der Nähe jubeln und Fotos machen .
#
# Vier Footballspieler in Schwarz tackeln im Regen einen Spieler der gegnerischen Mannschaft in Weiß .
#
# Ein Runner versucht , Extra @-@ Yards zu machen während er von zwei Tacklern zu Boden gebracht wird .
#
# Der Basketballspieler im weißen Trikot mit der Nummer 55 deckt den Spieler im schwarzen Trikot mit der Nummer 10.
#
# Ein Mann telefoniert im Freien mit dem Handy .
#
# Professionelle Baseballspieler beobachten beim All @-@ Star Game einen gegnerischen Batter .
#
# Ein Offroad @-@ Biker fährt im Herbst durch eine steile Kurve .
#
# 3 Basketballspieler kämpfen um den Ball , einer in einem roten Trikot versucht , einem in einem weißen Trikot den Ball wegzunehmen .
#
# Ein Junge greift sich ans Bein während er in die Luft springt .
#
# Zwei Kinder in gestreiften Sweatern und schwarzen Hosen rangeln im Freien neben einem Spielplatz .
#
# Ein Mann mit Sonnenbrille fährt auf einem Roller .
#
# Ein kleiner Junge in Baseballmontur holt mit einem Schläger hinter seinem Kopf in Richtung eines vor ihm montierten Baseballs aus .
#
# Sechs Männer sitzen auf einem Acker mit Holzkisten .
#
# Ein brauner Hund hebt einen Zweig von einer steinernen Oberfläche .
#
# Das ist ein gelb gekleideter Mann , der ein braunes Pferd an der Leine hält .
#
# Ein Mann in einem weißen Shirt und einer Schürze zerlegt einen Vogel .
#
# Eine hispanische Frau kocht im Freien in einem Wok .
#
# Marathonläuferinnen laufen auf einer städtischen Straße während andere Personen um sie herum stehen .
#
# Asiatische Frau trägt einen Sonnenhut beim Fahrradfahren .
#
# Ein paar Kinder sind im Freien und spielen auf dem Boden bei zwei Bäumen .
#
# Ein älterer Mann spielt ein Videospiel .
#
# Ein Mädchen an einer Küste mit einem Berg im Hintergrund .

# %%
from nltk.translate.bleu_score import sentence_bleu

bleu_sum = 0 

for i in range(len(pred)):
  candidate = pred[i].split()
  reference = lines[i].split()
  bleu = sentence_bleu(reference, candidate)
  bleu_sum += bleu

print(bleu_sum/1000)
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# 0.5331641162777885
